# %% [markdown]
# function to compute numpy representation from video file (thanks Yana!)

# %%
import numpy as np
import cv2
import os.path

# trs, let's assume width is always wider than height
def video_to_npy(infile, outfile=None, width=None, height=None, squarecrop=None, fps=None, cropat=None):
    
    # has this video already been saved before?
    if isfile(outfile):
        frames = np.load(outfile)
        if frames.shape[1]==height:
            # just return this preloaded video
            return frames
    
    print('reading fresh video from %s' % infile)
    vidcap = cv2.VideoCapture(infile)
    success, image = vidcap.read()
    
    frames = []
    count = 0
    if not success:
        raise ValueError('Could not read the video file!')
    while success:
        frames.append( image[...,::-1] )
        count += 1
        success,image = vidcap.read()
    if fps:
        span = int(vidcap.get(cv2.CAP_PROP_FPS) / fps)
        frames = frames[0::span] 
    if width or height:  
        width = width if width else int(height / frames[0].shape[0] * frames[0].shape[1])
        height = height if height else int(width / frames[0].shape[1] * frames[0].shape[0])
        frames = [ cv2.resize(frame, (width, height)) for frame in frames ]
    if squarecrop:
        tl = int((width/2)-(height/2))
        # note that x,y is the wrong way around i.e. it's
        # F x Y x X x C
        frames = [ frame[ 0:height, tl:(tl+height)] for frame in frames ]
    if cropat:
        frames = frames[0:cropat*fps]
        
    frames = np.array(frames)
    if outfile:
        np.save(outfile, frames)
    return frames

# %%
from random import shuffle
from pipe import *

@Pipe
def pshuffle(l):
    shuffle(l)
    return l
@Pipe
def pcycle(l):
    return cycle(l)

# %%
from os import listdir
from os.path import isfile, join
from itertools import *
from pipe import *

# return iterable { (label, path/video1), (label, path/video2), ... }
def GetVideos( path, label, ext='.mp4' ):
    p = listdir(path) | where( lambda p: p.endswith(ext) ) | as_list()
    return zip( repeat(label, len(p)), map( lambda p: join( path, p ), p ) )

# %%
import pickle
# dump a classes file so the others can see which classes I have assigned

classes = GetVideos('./videos/collisions', 1) \
    | chain_with(GetVideos('./videos/not-collisions', 0))  \
    | select( lambda i: (i[1].replace('./videos/collisions\\','').replace('./videos/not-collisions\\',''), i[0]) ) \
    | as_dict()

pickle.dump( classes, open( "class_structure.p", "wb" ) ) 

classes
# Out:
# {'output000-26961.mp4': 1,
#  'output000-5404.mp4': 1,
#  'output000.mp4': 1,
#  'output001-24132.mp4': 1,
#  'output001-24962.mp4': 1,
#  'output001-5404.mp4': 1,
#  'output001.mp4': 1,
#  'output002-26961.mp4': 1,
#  'output002-27378.mp4': 1,
#  'output002-4994.mp4': 1,
#  'output002-5404.mp4': 1,
#  'output002.mp4': 1,
#  'output003-24962.mp4': 1,
#  'output003-26961.mp4': 1,
#  'output003-27378.mp4': 1,
#  'output003-5404.mp4': 1,
#  'output003.mp4': 1,
#  'output004-27378.mp4': 1,
#  'output004-31027.mp4': 1,
#  'output004-4994.mp4': 1,
#  'output004-5404.mp4': 1,
#  'output004.mp4': 1,
#  'output005-26961.mp4': 1,
#  'output005-4360.mp4': 1,
#  'output005-5404.mp4': 1,
#  'output005.mp4': 1,
#  'output006-24132.mp4': 1,
#  'output006-24962.mp4': 1,
#  'output006-26961.mp4': 1,
#  'output006-27378.mp4': 1,
#  'output006-4994.mp4': 1,
#  'output006-5404.mp4': 1,
#  'output006.mp4': 1,
#  'output007-24962.mp4': 1,
#  'output007-26961.mp4': 1,
#  'output007-31027.mp4': 1,
#  'output007-4360.mp4': 1,
#  'output007-5404.mp4': 1,
#  'output007.mp4': 1,
#  'output008-24962.mp4': 1,
#  'output008-26961.mp4': 1,
#  'output008-27378.mp4': 1,
#  'output008-5404.mp4': 1,
#  'output008.mp4': 1,
#  'output009-26961.mp4': 1,
#  'output009-5404.mp4': 1,
#  'output009.mp4': 1,
#  'output010-26961.mp4': 1,
#  'output010-27378.mp4': 1,
#  'output010-5404.mp4': 1,
#  'output010.mp4': 1,
#  'output011-26961.mp4': 1,
#  'output011-27378.mp4': 1,
#  'output011-4994.mp4': 1,
#  'output011-5404.mp4': 1,
#  'output012-26961.mp4': 1,
#  'output012-27378.mp4': 1,
#  'output012-4994.mp4': 1,
#  'output012-5404.mp4': 1,
#  'output012.mp4': 1,
#  'output013-26961.mp4': 1,
#  'output013-27378.mp4': 1,
#  'output013-31027.mp4': 1,
#  'output013-5404.mp4': 1,
#  'output013.mp4': 1,
#  'output014-24962.mp4': 1,
#  'output014-26961.mp4': 1,
#  'output014-27378.mp4': 1,
#  'output014-31027.mp4': 1,
#  'output014-4994.mp4': 1,
#  'output014-5404.mp4': 1,
#  'output015-26961.mp4': 1,
#  'output015-27378.mp4': 1,
#  'output015-31027.mp4': 1,
#  'output015-4994.mp4': 1,
#  'output015.mp4': 1,
#  'output016-24962.mp4': 1,
#  'output016-26961.mp4': 1,
#  'output016.mp4': 1,
#  'output017-26961.mp4': 1,
#  'output017-5404.mp4': 1,
#  'output017.mp4': 1,
#  'output018-26961.mp4': 1,
#  'output018-5404.mp4': 1,
#  'output018.mp4': 1,
#  'output019-26961.mp4': 1,
#  'output019-5404.mp4': 1,
#  'output019.mp4': 1,
#  'output020-26961.mp4': 1,
#  'output020.mp4': 1,
#  'output021-24132.mp4': 1,
#  'output021-26961.mp4': 1,
#  'output021-4994.mp4': 1,
#  'output021.mp4': 1,
#  'output022-24962.mp4': 1,
#  'output022-26961.mp4': 1,
#  'output023-26961.mp4': 1,
#  'output023-27378.mp4': 1,
#  'output023-4994.mp4': 1,
#  'output023.mp4': 1,
#  'output024-5404.mp4': 1,
#  'output024.mp4': 1,
#  'output025-31027.mp4': 1,
#  'output026-24962.mp4': 1,
#  'output026-26961.mp4': 1,
#  'output026-5404.mp4': 1,
#  'output026.mp4': 1,
#  'output027-24132.mp4': 1,
#  'output027-24962.mp4': 1,
#  'output027-26961.mp4': 1,
#  'output027-5404.mp4': 1,
#  'output028-5404.mp4': 1,
#  'output028.mp4': 1,
#  'output029-24962.mp4': 1,
#  'output029-5404.mp4': 1,
#  'output029.mp4': 1,
#  'output030-24962.mp4': 1,
#  'output030-4360.mp4': 1,
#  'output030-5404.mp4': 1,
#  'output031-24132.mp4': 1,
#  'output031-24962.mp4': 1,
#  'output031-4994.mp4': 1,
#  'output031.mp4': 1,
#  'output032-24962.mp4': 1,
#  'output032-26961.mp4': 1,
#  'output032-4994.mp4': 1,
#  'output032-5404.mp4': 1,
#  'output033-27378.mp4': 1,
#  'output033-31027.mp4': 1,
#  'output034-26961.mp4': 1,
#  'output034-31027.mp4': 1,
#  'output034-4994.mp4': 1,
#  'output034-5404.mp4': 1,
#  'output035-26961.mp4': 1,
#  'output035-31027.mp4': 1,
#  'output035.mp4': 1,
#  'output036-24132.mp4': 1,
#  'output036-26961.mp4': 1,
#  'output036-31027.mp4': 1,
#  'output036-4994.mp4': 1,
#  'output036-5404.mp4': 1,
#  'output036.mp4': 1,
#  'output037-26961.mp4': 1,
#  'output037-5404.mp4': 1,
#  'output037.mp4': 1,
#  'output038-24132.mp4': 1,
#  'output038-24962.mp4': 1,
#  'output038-26961.mp4': 1,
#  'output038-5404.mp4': 1,
#  'output038.mp4': 1,
#  'output039-24132.mp4': 1,
#  'output039-5404.mp4': 1,
#  'output039.mp4': 1,
#  'output040.mp4': 1,
#  'output041-24132.mp4': 1,
#  'output041-26961.mp4': 1,
#  'output041-31027.mp4': 1,
#  'output041-4360.mp4': 1,
#  'output041-5404.mp4': 1,
#  'output041.mp4': 1,
#  'output042-26961.mp4': 1,
#  'output042-31027.mp4': 1,
#  'output042-5404.mp4': 1,
#  'output042.mp4': 1,
#  'output043-26961.mp4': 1,
#  'output043-5404.mp4': 1,
#  'output043.mp4': 1,
#  'output044-26961.mp4': 1,
#  'output044-4994.mp4': 1,
#  'output044-5404.mp4': 1,
#  'output045-26961.mp4': 1,
#  'output045-31027.mp4': 1,
#  'output045-5404.mp4': 1,
#  'output045.mp4': 1,
#  'output046-26961.mp4': 1,
#  'output046-31027.mp4': 1,
#  'output046-4360.mp4': 1,
#  'output046.mp4': 1,
#  'output047-26961.mp4': 1,
#  'output047.mp4': 1,
#  'output048-31027.mp4': 1,
#  'output048.mp4': 1,
#  'output049-24962.mp4': 1,
#  'output049-26961.mp4': 1,
#  'output049-5404.mp4': 1,
#  'output049.mp4': 1,
#  'output050-5404.mp4': 1,
#  'output051-24962.mp4': 1,
#  'output051-26961.mp4': 1,
#  'output051-31027.mp4': 1,
#  'output051-5404.mp4': 1,
#  'output051.mp4': 1,
#  'output052-26961.mp4': 1,
#  'output052-31027.mp4': 1,
#  'output052-4994.mp4': 1,
#  'output052-5404.mp4': 1,
#  'output052.mp4': 1,
#  'output053-26961.mp4': 1,
#  'output053-31027.mp4': 1,
#  'output053-5404.mp4': 1,
#  'output053.mp4': 1,
#  'output054-24962.mp4': 1,
#  'output054-26961.mp4': 1,
#  'output054.mp4': 1,
#  'output055-31027.mp4': 1,
#  'output055-5404.mp4': 1,
#  'output055.mp4': 1,
#  'output056-5404.mp4': 1,
#  'output056.mp4': 1,
#  'output057-26961.mp4': 1,
#  'output057-31027.mp4': 1,
#  'output057-5404.mp4': 1,
#  'output057.mp4': 1,
#  'output058-26961.mp4': 1,
#  'output058-5404.mp4': 1,
#  'output058.mp4': 1,
#  'output059-26961.mp4': 1,
#  'output059-4994.mp4': 1,
#  'output059.mp4': 1,
#  'output060-5404.mp4': 1,
#  'output061-26961.mp4': 1,
#  'output061-5404.mp4': 1,
#  'output061.mp4': 1,
#  'output062-26961.mp4': 1,
#  'output062-31027.mp4': 1,
#  'output062-5404.mp4': 1,
#  'output062.mp4': 1,
#  'output063-24962.mp4': 1,
#  'output063-26961.mp4': 1,
#  'output063-31027.mp4': 1,
#  'output063-5404.mp4': 1,
#  'output063.mp4': 1,
#  'output064-26961.mp4': 1,
#  'output064-4994.mp4': 1,
#  'output064-5404.mp4': 1,
#  'output064.mp4': 1,
#  'output065-26961.mp4': 1,
#  'output065-5404.mp4': 1,
#  'output065.mp4': 1,
#  'output066-26961.mp4': 1,
#  'output066-5404.mp4': 1,
#  'output066.mp4': 1,
#  'output067-24962.mp4': 1,
#  'output067-5404.mp4': 1,
#  'output067.mp4': 1,
#  'output068-26961.mp4': 1,
#  'output069-24962.mp4': 1,
#  'output069-26961.mp4': 1,
#  'output069.mp4': 1,
#  'output070-24132.mp4': 1,
#  'output070-24962.mp4': 1,
#  'output070-26961.mp4': 1,
#  'output070.mp4': 1,
#  'output071-24962.mp4': 1,
#  'output071-26961.mp4': 1,
#  'output071.mp4': 1,
#  'output072-26961.mp4': 1,
#  'output072-4360.mp4': 1,
#  'output072.mp4': 1,
#  'output073-31027.mp4': 1,
#  'output073.mp4': 1,
#  'output074-26961.mp4': 1,
#  'output074-31027.mp4': 1,
#  'output074-4360.mp4': 1,
#  'output074.mp4': 1,
#  'output075-24962.mp4': 1,
#  'output075-26961.mp4': 1,
#  'output075-31027.mp4': 1,
#  'output075.mp4': 1,
#  'output076-24962.mp4': 1,
#  'output076-31027.mp4': 1,
#  'output076.mp4': 1,
#  'output077-26961.mp4': 1,
#  'output077-31027.mp4': 1,
#  'output078-26961.mp4': 1,
#  'output079-26961.mp4': 1,
#  'output079.mp4': 1,
#  'output080-26961.mp4': 1,
#  'output080.mp4': 1,
#  'output081-26961.mp4': 1,
#  'output081-31027.mp4': 1,
#  'output082.mp4': 1,
#  'output083-26961.mp4': 1,
#  'output083.mp4': 1,
#  'output084-24962.mp4': 1,
#  'output084-26961.mp4': 1,
#  'output085-24962.mp4': 1,
#  'output085-26961.mp4': 1,
#  'output086-26961.mp4': 1,
#  'output086.mp4': 1,
#  'output087-24962.mp4': 1,
#  'output087-26961.mp4': 1,
#  'output087.mp4': 1,
#  'output088.mp4': 1,
#  'output089-26961.mp4': 1,
#  'output089.mp4': 1,
#  'output090-26961.mp4': 1,
#  'output090.mp4': 1,
#  'output091-24962.mp4': 1,
#  'output091-26961.mp4': 1,
#  'output091.mp4': 1,
#  'output092.mp4': 1,
#  'output094-24962.mp4': 1,
#  'output094-31027.mp4': 1,
#  'output094-4360.mp4': 1,
#  'output094.mp4': 1,
#  'output095-24962.mp4': 1,
#  'output095-31027.mp4': 1,
#  'output095-4360.mp4': 1,
#  'output095.mp4': 1,
#  'output096-31027.mp4': 1,
#  'output096.mp4': 1,
#  'output098.mp4': 1,
#  'output099-24132.mp4': 1,
#  'output099-4360.mp4': 1,
#  'output100-24132.mp4': 1,
#  'output100-4360.mp4': 1,
#  'output100.mp4': 1,
#  'output101.mp4': 1,
#  'output102.mp4': 1,
#  'output103-24962.mp4': 1,
#  'output103.mp4': 1,
#  'output104-4360.mp4': 1,
#  'output104.mp4': 1,
#  'output106-24132.mp4': 1,
#  'output106.mp4': 1,
#  'output107.mp4': 1,
#  'output108-31027.mp4': 1,
#  'output108.mp4': 1,
#  'output109.mp4': 1,
#  'output111.mp4': 1,
#  'output113.mp4': 1,
#  'output116.mp4': 1,
#  'output117.mp4': 1,
#  'output118.mp4': 1,
#  'output120.mp4': 1,
#  'output121-31027.mp4': 1,
#  'output121.mp4': 1,
#  'output122-31027.mp4': 1,
#  'output122.mp4': 1,
#  'output123.mp4': 1,
#  'output124.mp4': 1,
#  'output125.mp4': 1,
#  'output127.mp4': 1,
#  'output132.mp4': 1,
#  'output133.mp4': 1,
#  'output134.mp4': 1,
#  'output135.mp4': 1,
#  'output139-31027.mp4': 1,
#  'output145-31027.mp4': 1,
#  'output150-31027.mp4': 1,
#  'output001-26961.mp4': 0,
#  'output001-27378.mp4': 0,
#  'output004-26961.mp4': 0,
#  'output005-27378.mp4': 0,
#  'output006-14767.mp4': 0,
#  'output007-14767.mp4': 0,
#  'output007-27378.mp4': 0,
#  'output008-14767.mp4': 0,
#  'output009-14767.mp4': 0,
#  'output009-27378.mp4': 0,
#  'output011-14767.mp4': 0,
#  'output012-14767.mp4': 0,
#  'output013-14767.mp4': 0,
#  'output014-14767.mp4': 0,
#  'output014.mp4': 0,
#  'output015-14767.mp4': 0,
#  'output015-5404.mp4': 0,
#  'output016-27378.mp4': 0,
#  'output016-5404.mp4': 0,
#  'output017-27378.mp4': 0,
#  'output018-27378.mp4': 0,
#  'output019-27378.mp4': 0,
#  'output020-27378.mp4': 0,
#  'output020-5404.mp4': 0,
#  'output021-27378.mp4': 0,
#  'output022-27378.mp4': 0,
#  'output022.mp4': 0,
#  'output023-5404.mp4': 0,
#  'output024-26961.mp4': 0,
#  'output024-27378.mp4': 0,
#  'output025-26961.mp4': 0,
#  'output025-27378.mp4': 0,
#  'output025-5404.mp4': 0,
#  'output025.mp4': 0,
#  'output026-27378.mp4': 0,
#  'output027-27378.mp4': 0,
#  'output027.mp4': 0,
#  'output028-26961.mp4': 0,
#  'output028-27378.mp4': 0,
#  'output029-26961.mp4': 0,
#  'output029-27378.mp4': 0,
#  'output030-26961.mp4': 0,
#  'output030-27378.mp4': 0,
#  'output030.mp4': 0,
#  'output031-26961.mp4': 0,
#  'output031-27378.mp4': 0,
#  'output031-5404.mp4': 0,
#  'output032-27378.mp4': 0,
#  'output032.mp4': 0,
#  'output033-26961.mp4': 0,
#  'output033-5404.mp4': 0,
#  'output033.mp4': 0,
#  'output034-27378.mp4': 0,
#  'output034.mp4': 0,
#  'output035-27378.mp4': 0,
#  'output035-5404.mp4': 0,
#  'output036-27378.mp4': 0,
#  'output037-27378.mp4': 0,
#  'output038-27378.mp4': 0,
#  'output039-26961.mp4': 0,
#  'output040-26961.mp4': 0,
#  'output040-5404.mp4': 0,
#  'output044.mp4': 0,
#  'output046-5404.mp4': 0,
#  'output047-5404.mp4': 0,
#  'output048-26961.mp4': 0,
#  'output048-5404.mp4': 0,
#  'output050-26961.mp4': 0,
#  'output050.mp4': 0,
#  'output054-5404.mp4': 0,
#  'output059-5404.mp4': 0,
#  'output060-26961.mp4': 0,
#  'output060.mp4': 0,
#  'output067-26961.mp4': 0,
#  'output068.mp4': 0,
#  'output071-14767.mp4': 0,
#  'output072-14767.mp4': 0,
#  'output073-14767.mp4': 0,
#  'output073-26961.mp4': 0,
#  'output074-14767.mp4': 0,
#  'output075-14767.mp4': 0,
#  'output076-26961.mp4': 0,
#  'output077.mp4': 0,
#  'output081.mp4': 0,
#  'output082-26961.mp4': 0,
#  'output084.mp4': 0,
#  'output085.mp4': 0,
#  'output088-26961.mp4': 0,
#  'output092-26961.mp4': 0,
#  'output093.mp4': 0,
#  'output097-14767.mp4': 0,
#  'output097.mp4': 0,
#  'output098-14767.mp4': 0,
#  'output099-14767.mp4': 0,
#  'output099.mp4': 0,
#  'output100-14767.mp4': 0,
#  'output105.mp4': 0,
#  'output110.mp4': 0,
#  'output112.mp4': 0,
#  'output114.mp4': 0,
#  'output115.mp4': 0,
#  'output119-14767.mp4': 0,
#  'output119.mp4': 0,
#  'output120-14767.mp4': 0,
#  'output121-14767.mp4': 0,
#  'output122-14767.mp4': 0,
#  'output123-14767.mp4': 0,
#  'output124-14767.mp4': 0,
#  'output125-14767.mp4': 0,
#  'output126-14767.mp4': 0,
#  'output126.mp4': 0,
#  'output128.mp4': 0,
#  'output129.mp4': 0,
#  'output130.mp4': 0,
#  'output210-14767.mp4': 0,
#  'output211-14767.mp4': 0,
#  'output212-14767.mp4': 0,
#  'output213-14767.mp4': 0,
#  'output214-14767.mp4': 0,
#  'output215-14767.mp4': 0,
#  'output220-14767.mp4': 0,
#  'output221-14767.mp4': 0,
#  'output230-14767.mp4': 0,
#  'output231-14767.mp4': 0,
#  'output232-14767.mp4': 0,
#  'output233-14767.mp4': 0,
#  'output234-14767.mp4': 0,
#  'output237-14767.mp4': 0,
#  'output238-14767.mp4': 0,
#  'output239-14767.mp4': 0,
#  'output240-14767.mp4': 0,
#  'output241-14767.mp4': 0,
#  'output345-14767.mp4': 0,
#  'output346-14767.mp4': 0,
#  'output347-14767.mp4': 0,
#  'output348-14767.mp4': 0,
#  'output349-14767.mp4': 0,
#  'output379-14767.mp4': 0,
#  'output380-14767.mp4': 0,
#  'output381-14767.mp4': 0,
#  'output406-14767.mp4': 0,
#  'output407-14767.mp4': 0,
#  'output408-14767.mp4': 0,
#  'output440-14767.mp4': 0,
#  'output441-14767.mp4': 0,
#  'output442-14767.mp4': 0,
#  'output443-14767.mp4': 0,
#  'output444-14767.mp4': 0,
#  'output470-14767.mp4': 0,
#  'output471-14767.mp4': 0,
#  'output472-14767.mp4': 0,
#  'output473-14767.mp4': 0,
#  'output474-14767.mp4': 0,
#  'output475-14767.mp4': 0,
#  'output540-14767.mp4': 0,
#  'output541-14767.mp4': 0,
#  'output542-14767.mp4': 0,
#  'output543-14767.mp4': 0,
#  'output544-14767.mp4': 0,
#  'output545-14767.mp4': 0,
#  'output594-14767.mp4': 0,
#  'output595-14767.mp4': 0,
#  'output596-14767.mp4': 0,
#  'output597-14767.mp4': 0,
#  'output646-14767.mp4': 0,
#  'output647-14767.mp4': 0,
#  'output648-14767.mp4': 0,
#  'output649-14767.mp4': 0,
#  'output650-14767.mp4': 0,
#  'output651-14767.mp4': 0,
#  'output676-14767.mp4': 0,
#  'output677-14767.mp4': 0,
#  'output678-14767.mp4': 0,
#  'output679-14767.mp4': 0,
#  'output680-14767.mp4': 0,
#  'output681-14767.mp4': 0,
#  'output688-14767.mp4': 0,
#  'output689-14767.mp4': 0,
#  'output690-14767.mp4': 0,
#  'output691-14767.mp4': 0,
#  'output692-14767.mp4': 0}

# %%
import uuid
import pickle
import math

collisions = GetVideos('./videos/collisions', 1) | as_list() | pshuffle()
ncollisions = GetVideos('./videos/not-collisions', 0) | as_list() | pshuffle()

# what is the min number in either class?
minn = [ collisions | count, ncollisions | count ] | min

# now let's validate on 33% of that
vs = math.floor( minn * 0.33 )

# %%
# run this when you need to
#valset = collisions | take(vs) | chain_with( ncollisions | take(vs) ) | as_list()
# let's save this valsplit to the filesystem for use later!
#pickle.dump( valset, open( "valsplit_%s.p" % uuid.uuid4().hex, "wb" ) )

# %%
# are you running this later and want to pick up from a previous val split for consistent results?
# important; has the population of videos on the file system changed since this pickle was created?
import pickle
valset = pickle.load( open( "valsplit_1b46b8e12c244afdaf09f83241fb443a.p", "rb" ) )

# %%
# how many validation videos?
print(valset | count)
# Out:
# 118

# %%
# now let's get a stream of train and validation videos which is label-balanced 

def videoStream():
    # handy dict to see if a file is in the validation set
    vd = valset | select( lambda t: (t[1],t[0]) ) | as_dict()
    
    
    while True:
        
        #create an infinite sequence of both, taking the same from both to ensure 
        # same average label distribution
        ic = collisions | where( lambda v: v[1] not in vd ) | as_list() | pshuffle() | take(100)
        inc = ncollisions | where( lambda v: v[1] not in vd ) | as_list() | pshuffle() | take(100)

        mixed_stream = ( ic \
            | chain_with( inc )  \
            | as_list()
            # shuffle it so we get good label mix
            | pshuffle() )
        
        for e in mixed_stream:
            yield e

# %%
# this is our training stream which is label balanced
stream = videoStream()

# %%
# check no leakage between val set and training stream!
fir = valset | first()

for i in range(400):
    s = next(stream)
    print( '%s!=%s' % ( s[1],fir[1]  ) )
    assert( s[1] is not fir[1] )
# Out:
# ./videos/not-collisions\output440-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output008-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output121.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output110.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output651-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output039-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output054-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output044-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output000-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output002-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output646-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output017-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output058.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output010-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output690-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output001-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output099-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output688-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output009-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output025-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output689-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output041-4360.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output001-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output085-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output014-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output031-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output011-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output029-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output016-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output003-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output034-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output046-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output051-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output234-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output012.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output239-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output057-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output088-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output042.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output045.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output032-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output012-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output691-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output030.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output035-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output014-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output063-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output009-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output036-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output091-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output007-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output542-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output041-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output031-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output017-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output040-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output081.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output444-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output033-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output007.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output381-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output011-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output031-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output345-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output101.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output050-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output016-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output067.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output231-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output544-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output006-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output115.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output036.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output241-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output408-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output121-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output075-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output013-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output129.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output027-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output117.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output046.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output237-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output027-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output071-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output100-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output037-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output005-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output031-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output441-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output025-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output033-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output006-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output119.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output024-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output016-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output087.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output051.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output348-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output030-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output003-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output045-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output007-4360.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output062-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output030-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output059-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output021-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output054-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output021-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output077-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output649-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output380-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output032.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output094-4360.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output062-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output132.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output543-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output099.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output004-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output048-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output015-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output034.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output027-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output073.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output471-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output233-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output096-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output007-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output647-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output122-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output075-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output001-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output020-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output032-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output062.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output220-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output541-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output016.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output230-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output015-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output038-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output106.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output056.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output074.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output066-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output097.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output070-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output065-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output091.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output071.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output083.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output595-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output014-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output045-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output025-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output058-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output238-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output022-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output105.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output038-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output060.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output470-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output015.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output060-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output026-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output037-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output024-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output118.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output540-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output049.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output123.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output681-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output032-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output017-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output030-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output041-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output008-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output072-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output678-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output037.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output090-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output035-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output041-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output213-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output071-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output074-4360.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output072.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output077.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output049-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output074-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output002-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output680-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output074-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output078-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output012-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output240-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output125-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output072-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output034-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output471-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output061.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output003-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output130.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output230-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output018-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output012-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output134.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output597-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output221-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output678-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output007-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output032-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output015-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output212-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output017-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output115.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output004-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output001-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output055-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output088-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output596-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output119.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output029-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output001-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output071-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output440-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output001-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output060-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output442-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output046-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output006-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output040-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output037.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output008-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output026-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output069.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output110.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output039.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output012-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output381-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output056-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output063-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output099.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output125-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output019-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output051-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output038-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output018.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output034.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output129.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output003-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output011-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output081.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output689-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output091.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output025-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output036-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output032-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output015-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output089.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output036-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output649-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output044-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output031-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output062-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output031-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output075-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output031-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output035-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output051-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output213-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output072.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output075.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output015-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output081-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output075-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output003-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output031-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output001-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output121-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output025-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output238-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output380-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output055.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output085-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output005.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output049-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output345-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output095.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output541-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output008-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output014-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output106-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output048-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output069-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output062-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output021-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output027-24132.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output030-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output000-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output094-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output016.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output103-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output017.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output066-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output041-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output009-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output038.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output014-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output037-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output036-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output033-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output059.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output092-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output012-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output241-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output074-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output025-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output004-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output646-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output015.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output034-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output032-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output002.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output112.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output014-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output070-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output544-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output237-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output239-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output444-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output441-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output210-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output057-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output105.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output101.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output220-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output408-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output473-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output648-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output022-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output015-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output348-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output099-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output046-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output002-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output086-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output057.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output087-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output050-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output014-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output063-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output055-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output021-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output031-4994.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output054-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output074-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output072-4360.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output061-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output104-4360.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output067-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output007-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output543-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output097.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output023-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output215-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output009-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output084-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output005-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output234-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output060.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output070-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output045.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output059-26961.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output020-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output016-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output019-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output647-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output231-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output123.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output542-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output025-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output688-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output233-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output033-27378.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output540-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output003-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output095-31027.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output006-24962.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output676-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output681-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output595-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output052.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output024-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output033-5404.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output677-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/collisions\output067.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output680-14767.mp4!=./videos/collisions\output003.mp4
# ./videos/not-collisions\output030.mp4!=./videos/collisions\output003.mp4

# %% [markdown]
# for every video in the collisions/non collisions folder, compute the numpy representation

# %%
# adorn the video to the tuple iterator, return cloned+appended tuple
@Pipe
def adornVideo(iterator, framerate=25, video_size=64, max_length=5):
    return iterator \
        | select( lambda f: f + ( 
            video_to_npy( f[1], 
                         #note weird thing here, width doesn't work they appear to be inverted
                         height=video_size, 
                         squarecrop=True, 
                         fps=framerate,
                         cropat=max_length,
                         # save a npy replacement
                         outfile=f[1].replace('.mp4','_%d.npy' % (video_size) )
            ), ) )

# %% [markdown]
# ok, so at this point we now have a numpy array for every single video file! the numpy arrays are fixed on some video size, length and frame rate i.e. 200^2, 5 seconds and 25fps.

# %% [markdown]
# For every single video file, we compute a random augmentation consistently across all of the frames

# %%
import random

from keras.preprocessing.image import ImageDataGenerator

data_gen_args = dict(featurewise_center=False,
                     featurewise_std_normalization=False,
                     rotation_range=5,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=0.1,
                     horizontal_flip=True)

image_datagen = ImageDataGenerator(**data_gen_args)

@Pipe
def augmentation( 
    flow,
    colpath='./collisions',
    noncolpath='./not-collisions',
    augment=True, 
    diff=False,
    normalize=True):
   
    for video in flow:
        # for every frame in this video generate the same transformation
        # and yield it all back in sequence order
        trans = image_datagen.get_random_transform(video[2].shape)
        augmentedVideo = np.zeros( video[2].shape )
        for i in range(video[2].shape[0]):
            if augment:
                augmentedVideo[i] = image_datagen.apply_transform(video[2][i], trans)
            else:
                augmentedVideo[i] = video[2][i]
            
            # now is a good time to transform the video onto 0-1
            # we need to do this to get convergence when we train i.e. homogenise features
            if normalize:
                augmentedVideo[i] = augmentedVideo[i] / 255
            
            # take xth order differences of frames to convey pixel-wise temporal changes
            if diff is not None:
                augmentedVideo[i, 0:augmentedVideo[i].shape[0]-diff] = np.diff(augmentedVideo[i], axis=0, n=diff)
            
        yield video[:-1] + (augmentedVideo,)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# let's visualize the augmented results for this video

# %%
import matplotlib.pyplot as plt

def show_images(images, cols = 1, titles = None):
    assert((titles is None)or (len(images) == len(titles)))
    n_images = len(images)
    if titles is None: titles = ['Image (%d)' % i for i in range(1,n_images + 1)]
    fig = plt.figure()
    for n, (image, title) in enumerate(zip(images, titles)):
        a = fig.add_subplot(cols, np.ceil(n_images/float(cols)), n + 1)
        if image.ndim == 2:
            plt.gray()
        plt.imshow(image)
        a.set_title(title)
        plt.xticks([]), plt.yticks([])
    fig.set_size_inches(np.array(fig.get_size_inches()) * n_images)
    plt.tight_layout()
    plt.show()
    display()

# %%
train_withvideo_aug = stream |  adornVideo() | augmentation(diff=None, augment=True)
val_withvideo = valset | adornVideo()

def getTestImages(flow, howmany=5):
    augmentedVideo = next(flow)
    print(augmentedVideo[2].shape)
    return range(augmentedVideo[2].shape[0]) \
        | select( lambda i: augmentedVideo[2][i] ) \
        | take(howmany) 

# show some augmented train images
images = getTestImages(train_withvideo_aug)

for x in range(2):
    images = images | chain_with( getTestImages(train_withvideo_aug) )

show_images( images | as_list, cols=4 )

# and do the same for some validation images
images = getTestImages(val_withvideo)
for x in range(2):
    images = images | chain_with( getTestImages(val_withvideo) )

show_images( images | as_list, cols=4 )

# %% [markdown]
# ok this is looking pretty good, next thing is to zeropad so that the number of frames is always the same i.e. max seconds * framerate

# %%
@Pipe
def zeroPadVideos(videoStream, video_size=64, max_length=5, framerate=25):
    for video in videoStream:
        zeroPadded = np.zeros( ( max_length * framerate, video_size, video_size, 3 ) )
        zeroPadded[ 0:video[2].shape[0], :, : ,: ] = video[2]
        yield video[:-1] + (zeroPadded,)

# we will need to do the same thing to the validation stream as what happened to the train stream!
@Pipe
def normalizeVideos(videoStream):
    for video in videoStream:
        
        yield ( video[0], video[1], video[2]/255  )

# %% [markdown]
# OK the next problem is we have a nice generator for videos, but we are doing a 4d CNN with videos and need a batch dimension, so let's write another generator which will batch X videos at a time
#
# ```
# next( zeroPadVideos( flow ) )[3].shape
# ```
# == (125, 200, 200, 3)

# %%
@Pipe
def getBatchVideosFlow(flow, batchsize=10, video_size=64, max_length=5, framerate=25):
    while(True):
        batch = np.zeros( (batchsize, max_length * framerate, video_size, video_size, 3 ) )
        labels = np.zeros( (batchsize,1))
        for i in range(batchsize):
            video = next( flow )
            batch[i] = video[2]
            labels[i] = video[0]
        yield ( batch, labels )

# %% [markdown]
# We now have a generator giving us batches of training examples and respective labels, we can feed this into keras fit_generator!

# %% [markdown]
# How big is a batch i.e. will it fit in memory?

# %%
# %%time
from sys import getsizeof

g = train_withvideo_aug = stream \
    |  adornVideo()  \
    | augmentation(diff=None, augment=True)  \
    | zeroPadVideos()  \
    |  getBatchVideosFlow(5)

r = next( g )
# signals one for each video
print(r[0].shape)
# labels one for each video
print(r[1].shape)

print(getsizeof(r[0])/1024**3)
# == 2.4gb for 20 videos of 125 frames @ 200^2*3

# clear r
r=0
# Out:
# (5, 125, 64, 64, 3)
# (5, 1)
# 0.05722060799598694
# Wall time: 346 ms

# %% [markdown]
# now let's try and train keras on it

# %%
video_size = 32
framerate = 25
max_length = 5
batchsize = 10

print('training with videosize: %s framerate: %d' % (video_size, framerate))

# make a fresh stream for clarity
train_stream = ( videoStream() 
    # actually load the respective video into memory
    | adornVideo(framerate=framerate, video_size=video_size, max_length=max_length) 
    # for all frames in this video, randomly augment them in the same way
    | augmentation(diff=True, augment=False, normalize=True) 
    | normalizeVideos()
    | zeroPadVideos(video_size) 
    # batch into X videos to match Keras modality
    | getBatchVideosFlow( batchsize, video_size ) )

# recall valset is our precomputed list of validation videos (50/50 label split)
val_stream = ( valset 
    | adornVideo(framerate=framerate, video_size=video_size, max_length=max_length) 
    | normalizeVideos()
    | zeroPadVideos(video_size) 
    # we need this to be an infinite sequence for Keras but fear not
    # all validation samples will be returned before a cycle
    | pcycle() 
    | getBatchVideosFlow( batchsize, video_size ) )
# Out:
# training with videosize: 32 framerate: 25

# %%
from keras import layers
from keras import models
from keras import regularizers

prelu = layers.advanced_activations.ReLU()

model = models.Sequential()
model.add(layers.Conv3D(32, (3, 3, 3), input_shape=(max_length * framerate, video_size, video_size, 3)))
model.add(prelu)
model.add(layers.MaxPooling3D((3, 3, 3)))
model.add(layers.Conv3D(128, (3, 3, 3) ))
model.add(prelu)
model.add(layers.MaxPooling3D((3, 3, 3)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.3))
model.add(layers.Dense(20))
model.add(prelu)
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_5 (Conv3D)            (None, 123, 30, 30, 32)   2624
# _________________________________________________________________
# re_lu_3 (ReLU)               multiple                  0
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 41, 10, 10, 32)    0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 39, 8, 8, 128)     110720
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 13, 2, 2, 128)     0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6656)              0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6656)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 20)                133140
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 246,505
# Trainable params: 246,505
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers
from keras import callbacks

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.SGD(lr=0.01,momentum=0.1,nesterov=True),
              metrics=['acc'])

filepath="weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5"

checkpoint =  callbacks.ModelCheckpoint(filepath, 
                          monitor='val_loss', 
                          verbose=0, 
                          save_best_only=False, 
                          save_weights_only=False, 
                          mode='auto', 
                          period=1)

history = model.fit_generator(
      train_stream,
      steps_per_epoch=40, 
      validation_data=val_stream, 
      # has to be false on windows..
      use_multiprocessing=False, 
      validation_steps = 50,
      epochs=10,
      callbacks = [checkpoint])
# Out:
# Epoch 1/10
# 40/40 [==============================] - 5s 122ms/step - loss: 0.6939 - acc: 0.5025 - val_loss: 0.7268 - val_acc: 0.4800
# Epoch 2/10
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6939 - acc: 0.5050 - val_loss: 0.7265 - val_acc: 0.4800
# Epoch 3/10
# 40/40 [==============================] - 4s 92ms/step - loss: 0.6936 - acc: 0.4950 - val_loss: 0.7036 - val_acc: 0.5220
# Epoch 4/10
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6934 - acc: 0.4875 - val_loss: 0.7015 - val_acc: 0.5280
# Epoch 5/10
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6936 - acc: 0.4650 - val_loss: 0.7256 - val_acc: 0.4840
# Epoch 6/10
# 40/40 [==============================] - 4s 94ms/step - loss: 0.6937 - acc: 0.4950 - val_loss: 0.7288 - val_acc: 0.4720
# Epoch 7/10
# 40/40 [==============================] - 4s 93ms/step - loss: 0.6936 - acc: 0.4600 - val_loss: 0.7097 - val_acc: 0.5100
# Epoch 8/10
# 36/40 [==========================>...] - ETA: 0s - loss: 0.6934 - acc: 0.4639
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-38744d6c91d2> in <module>()
#      24       validation_steps = 50,
#      25       epochs=10,
# ---> 26       callbacks = [checkpoint])
#
# c:\program files\python36\lib\site-packages\keras\legacy\interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# c:\program files\python36\lib\site-packages\keras\engine\training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# c:\program files\python36\lib\site-packages\keras\engine\training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     175             batch_index = 0
#     176             while steps_done < steps_per_epoch:
# --> 177                 generator_output = next(output_generator)
#     178
#     179                 if not hasattr(generator_output, '__len__'):
#
# c:\program files\python36\lib\site-packages\keras\utils\data_utils.py in get(self)
#     785                     raise StopIteration()
#     786                 else:
# --> 787                     time.sleep(self.wait_time)
#     788
#     789         # Make sure to rethrow the first exception in the queue, if any
#
# KeyboardInterrupt:

# %% [markdown]
# Now we plot to see the convergence behaviour and overfitting

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']


f, (ax1,ax2) = plt.subplots(2,1)

epochs = range(len(acc))

ax1.plot(epochs, acc, 'bo', label='Training acc')
ax1.plot(epochs, val_acc, 'b', label='Validation acc')
ax1.set_title('Training and validation accuracy')
ax1.legend()


ax2.plot(epochs, loss, 'bo', label='Training loss')
ax2.plot(epochs, val_loss, 'b', label='Validation loss')
ax2.set_title('Training and validation loss')
ax2.legend()

plt.show()
