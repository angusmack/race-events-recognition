# %% [markdown]
# # Acronis Collision Detection

# %%
import sys
# !{sys.executable} -m pip install pipe
# Out:
# Requirement already satisfied: pipe in c:\anaconda\envs\py35\lib\site-packages (1.5.0)
# C:\Anaconda\envs\py35\python.exe
# pyspark 2.2.0 requires py4j==0.10.4, which is not installed.
# azure 2.0.0 has requirement azure-graphrbac~=0.30.0, but you'll have azure-graphrbac 0.31.0 which is incompatible.
# keras-applications 1.0.4 has requirement keras>=2.1.6, but you'll have keras 2.0.8 which is incompatible.
# keras-preprocessing 1.0.2 has requirement keras>=2.1.6, but you'll have keras 2.0.8 which is incompatible.
# tensorflow-tensorboard 0.1.8 has requirement html5lib==0.9999999, but you'll have html5lib 0.999999999 which is incompatible.
# bleach 1.5.0 has requirement html5lib!=0.9999,!=0.99999,<0.99999999,>=0.999, but you'll have html5lib 0.999999999 which is incompatible.
# azure-mgmt 1.0.0 has requirement azure-mgmt-datalake-analytics~=0.1.4, but you'll have azure-mgmt-datalake-analytics 0.2.0 which is incompatible.
# azure-mgmt 1.0.0 has requirement azure-mgmt-datalake-store~=0.1.4, but you'll have azure-mgmt-datalake-store 0.2.0 which is incompatible.
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
import numpy as np
import cv2
from utils.image import *
from utils.video import *
from utils.pipeutils import *
import os
from os.path import join,isfile,isdir
from os import listdir
from pipe import *
import random
import matplotlib.pyplot as plt
import math
import builtins

# %% [markdown]
# ### Initial configuration

# %%
base_dir = 'd:\\data'

# %% [markdown]
# `GetFiles` is the function that will return a generator containing files in given directory with given extension, and specified `label`

# %%
# return iterable { (label, path/video1), (label, path/video2), ... }
def GetFiles( path, label, ext ):
    global base_dir
    d = join(base_dir,path)
    p = listdir(d) | where( lambda p: p.endswith(ext) ) | as_list()
    return zip(np.repeat(label, len(p)), map( lambda p: join( base_dir, path, p ), p ) )

videos = GetFiles('train\\collisions', 1, ext='.mp4') \
            | chain_with( GetFiles('val\\not-collisions', 0, ext='.mp4') ) \
            | chain_with( GetFiles('train\\not-collisions', 0, ext='.mp4') ) \
            | chain_with( GetFiles('val\\collisions', 1, ext='.mp4') ) \
            | as_list

framerate = 25
video_size = 64
max_length = 5

# adorn the video to the tuple iterator, return cloned+appended tuple
def adornVideo(iterator, video_size=video_size, squarecrop=True):
    return iterator \
        | select( lambda f: f + ( 
            video_to_npy( f[1], 
                         #note weird thing here, width doesn't work they appear to be inverted
                         height=video_size, 
                         squarecrop=squarecrop, 
                         fps=framerate,
                         cropat=max_length
            ), ) )

# %% [markdown]
# ### Define useful video functions

# %%
## Compute Dense Optical Flow
sample = adornVideo(videos,video_size=300,squarecrop=False) | skip(3) | take(1) | as_list
frames = sample[0][2][:,:,:,0:5]
show_images(frames[0:5])
# Out:
# reading video from d:\data\train\collisions\output000-26961.mp4
# reading video from d:\data\train\collisions\output000.mp4
# reading video from d:\data\train\collisions\output001.mp4
# reading video from d:\data\train\collisions\output002-27378.mp4
# reading video from d:\data\train\collisions\output002.mp4

# %%
# get n sample frames from the video
def sample_idx(video,n=5):
    return range(0,len(video),len(video)//n)

def sample_frames(video,n=5):
    return video[sample_idx(video)]

fs = sample_frames(frames)
show_images(fs)

# %% [markdown]
# ## Compute dense optical flow

# %%
def dense_flow(frame1, frame2):
    f1 = cv2.cvtColor(frame1,cv2.COLOR_BGR2GRAY)
    f2 = cv2.cvtColor(frame2,cv2.COLOR_BGR2GRAY)
    return cv2.calcOpticalFlowFarneback(f1, f2, None, 0.5, 3, 15, 3, 5, 1.2, 0)

def visualize_flow_hsv(frame1, flow):
    hsvImg = np.zeros_like(frame1)
    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    hsvImg[..., 0] = 0.5 * ang * 180 / np.pi
    hsvImg[..., 1] = 255
    hsvImg[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    return cv2.cvtColor(hsvImg, cv2.COLOR_HSV2BGR)

show_images([visualize_flow_hsv(frames[i],dense_flow(frames[i],frames[i+1])) for i in sample_idx(frames)])

# %%
# Some naive stabilization
def dense_flow_stab(frame1, frame2):
    f = dense_flow(frame1, frame2)
    vec = np.average(f,axis=(0,1))
    mask = f==0
    f = f-vec
    f[mask]=0
    return f

show_images([visualize_flow_hsv(frames[i],dense_flow_stab(frames[i],frames[i+1])) for i in sample_idx(frames)])

# %% [markdown]
# Histograms of x and y displacements

# %%
fs = [dense_flow(frames[i],frames[i+1]) for i in sample_idx(frames)]
fig, ax = plt.subplots(5,2)
for i,x in enumerate(fs):
    ax[i,0].hist(x[:,:,0].ravel())
    ax[i,1].hist(x[:,:,1].ravel())
plt.show()

# %% [markdown]
# Histogram of direction/magnitude

# %%
fs = [dense_flow(frames[i],frames[i+1]) for i in range(0,len(frames),len(frames)//5)]
fig, ax = plt.subplots(6,2)
for i,x in enumerate(fs):
    mag, ang = cv2.cartToPolar(x[..., 0], x[..., 1])
    ax[i,0].hist(mag[:,:].ravel())
    ax[i,1].hist(ang[:,:].ravel())
plt.show()

# %% [markdown]
# Computing histogram for the whole video

# %%
flow = np.array([dense_flow(frames[i],frames[i+1]) for i in range(0,len(frames)-1)])
mag, ang = cv2.cartToPolar(flow[...,0],flow[...,1])
fig,ax=plt.subplots(2,2,figsize=(15,6))
ax[0,0].hist(flow[...,0].ravel(),bins=50); ax[0,0].set_title('X')
ax[0,1].hist(flow[...,1].ravel(),bins=50); ax[0,1].set_title('Y')
ax[1,0].hist(mag.ravel(),bins=50); ax[1,0].set_title('Magnitude')
ax[1,1].hist(ang.ravel(),bins=50); ax[1,1].set_title('Angle')
plt.show()
print("Max magnitude={}".format(mag.max()))
# Out:
# Max magnitude=64.23680877685547

# %%
fig,ax=plt.subplots(2,1,figsize=(10,6))
ax[0].hist(np.log(mag.ravel()),bins=50); ax[0].set_title('Log Magnitude')
ax[1].hist(1/(1+np.exp(-mag.ravel())),bins=50); ax[1].set_title('Sigmoid Magnitude')
plt.show()

# %%
fs = [dense_flow(frames[i],frames[i+1]) for i in range(0,len(frames),len(frames)//5)]
nbins=100
fig, ax = plt.subplots(5,2)
max_mag = 0
for i,x in enumerate(fs):
    mag, ang = cv2.cartToPolar(x[..., 0], x[..., 1])
    ax[i,0].plot(np.log(np.histogram(mag.ravel(),bins=np.arange(nbins)/nbins*10-5)[0])) # we consider log in range -5..5
    ax[i,1].plot(np.histogram(ang.ravel(),bins=np.arange(nbins)/nbins*2*math.pi)[0])
    max_mag=builtins.max(max_mag,mag.max())
plt.show()
print("Max magnitude={}".format(max_mag))
# Out:
# C:\Anaconda\envs\py35\lib\site-packages\ipykernel\__main__.py:7: RuntimeWarning: divide by zero encountered in log
# Max magnitude=33.01518249511719

# %%
def get_flow_descriptor(video,nbins=100,mag_min=-7,max_max=7):
    def descr(f1,f2,bins,mbins):
        f = dense_flow_stab(f1,f2)
        mag, ang = cv2.cartToPolar(f[..., 0], f[..., 1])
        h1,bins1 = np.histogram(ang.ravel(),bins=bins)
        h2,bins2 = np.histogram(mag.ravel(),bins=mbins)
        return [[x,y] for x,y in zip(h1,np.log(1+h2))] # we take log of histograms to make range smaller
    abins = [i*2*math.pi/nbins for i in range(0,nbins+1)]
    mbins = np.arange(nbins+1)/nbins*(max_mag-mag_min)+mag_min
    return np.array([ descr(video[i],video[i+1],bins=abins,mbins=mbins) for i in range(0,len(video)-1)])

fd = get_flow_descriptor(frames)
print(frames.shape, fd.shape)
# Out:
# (125, 300, 533, 3) (124, 100, 2)

# %%
#fd = get_flow_descriptor(frames)
dx=90
fig, ax = plt.subplots(10,3,figsize=(15,15))
for i in range(0,10):
    ax[i,0].imshow(frames[i+dx])
    ax[i,1].plot(fd[i+dx,:,0])
    ax[i,2].plot(fd[i+dx,:,1])
plt.show()

# %% [markdown]
# ## Store optical flow information on disk

# %%
to_process_flows = videos \
                | where( lambda f: not isfile( f[1].replace('.mp4','.flows.npy') ) )

flows_withvideo = adornVideo(to_process_flows, video_size=300)

# write out the vectorflows for each video
for v in flows_withvideo:
    hist = get_flow_descriptor(v[2])
    np.save(v[1].replace('.mp4','.flows.npy'),hist)
# Out:
# reading video from d:\data\train\collisions\output000-26961.mp4
# reading video from d:\data\train\collisions\output000.mp4
# reading video from d:\data\train\collisions\output001.mp4
# reading video from d:\data\train\collisions\output002-27378.mp4
# reading video from d:\data\train\collisions\output002.mp4
# reading video from d:\data\train\collisions\output003-27378.mp4
# reading video from d:\data\train\collisions\output003-5404.mp4
# reading video from d:\data\train\collisions\output003.mp4
# reading video from d:\data\train\collisions\output005-5404.mp4
# reading video from d:\data\train\collisions\output005.mp4
# reading video from d:\data\train\collisions\output006-26961.mp4
# reading video from d:\data\train\collisions\output006-27378.mp4
# reading video from d:\data\train\collisions\output006.mp4
# reading video from d:\data\train\collisions\output008-27378.mp4
# reading video from d:\data\train\collisions\output008-5404.mp4
# reading video from d:\data\train\collisions\output008.mp4
# reading video from d:\data\train\collisions\output009-26961.mp4
# reading video from d:\data\train\collisions\output009-5404.mp4
# reading video from d:\data\train\collisions\output009.mp4
# reading video from d:\data\train\collisions\output011-26961.mp4
# reading video from d:\data\train\collisions\output011-5404.mp4
# reading video from d:\data\train\collisions\output012.mp4
# reading video from d:\data\train\collisions\output013-26961.mp4
# reading video from d:\data\train\collisions\output013-27378.mp4
# reading video from d:\data\train\collisions\output013-5404.mp4
# reading video from d:\data\train\collisions\output014-26961.mp4
# reading video from d:\data\train\collisions\output014-27378.mp4
# reading video from d:\data\train\collisions\output016.mp4
# reading video from d:\data\train\collisions\output017-26961.mp4
# reading video from d:\data\train\collisions\output017-5404.mp4
# reading video from d:\data\train\collisions\output017.mp4
# reading video from d:\data\train\collisions\output018.mp4
# reading video from d:\data\train\collisions\output019-5404.mp4
# reading video from d:\data\train\collisions\output020-26961.mp4
# reading video from d:\data\train\collisions\output020.mp4
# reading video from d:\data\train\collisions\output021-26961.mp4
# reading video from d:\data\train\collisions\output023-27378.mp4
# reading video from d:\data\train\collisions\output024-5404.mp4
# reading video from d:\data\train\collisions\output024.mp4
# reading video from d:\data\train\collisions\output027-26961.mp4
# reading video from d:\data\train\collisions\output027-5404.mp4
# reading video from d:\data\train\collisions\output030-5404.mp4
# reading video from d:\data\train\collisions\output032-26961.mp4
# reading video from d:\data\train\collisions\output032-5404.mp4
# reading video from d:\data\train\collisions\output034-26961.mp4
# reading video from d:\data\train\collisions\output035.mp4
# reading video from d:\data\train\collisions\output036-5404.mp4
# reading video from d:\data\train\collisions\output037-26961.mp4
# reading video from d:\data\train\collisions\output037.mp4
# reading video from d:\data\train\collisions\output039.mp4
# reading video from d:\data\train\collisions\output040.mp4
# reading video from d:\data\train\collisions\output041.mp4
# reading video from d:\data\train\collisions\output043.mp4
# reading video from d:\data\train\collisions\output045-26961.mp4
# reading video from d:\data\train\collisions\output045.mp4
# reading video from d:\data\train\collisions\output047.mp4
# reading video from d:\data\train\collisions\output049.mp4
# reading video from d:\data\train\collisions\output050-5404.mp4
# reading video from d:\data\train\collisions\output051.mp4
# reading video from d:\data\train\collisions\output052.mp4
# reading video from d:\data\train\collisions\output054-26961.mp4
# reading video from d:\data\train\collisions\output054.mp4
# reading video from d:\data\train\collisions\output056-5404.mp4
# reading video from d:\data\train\collisions\output057.mp4
# reading video from d:\data\train\collisions\output058-5404.mp4
# reading video from d:\data\train\collisions\output058.mp4
# reading video from d:\data\train\collisions\output059.mp4
# reading video from d:\data\train\collisions\output060-5404.mp4
# reading video from d:\data\train\collisions\output061-26961.mp4
# reading video from d:\data\train\collisions\output061-5404.mp4
# reading video from d:\data\train\collisions\output062-26961.mp4
# reading video from d:\data\train\collisions\output062-5404.mp4
# reading video from d:\data\train\collisions\output062.mp4
# reading video from d:\data\train\collisions\output063-26961.mp4
# reading video from d:\data\train\collisions\output063-5404.mp4
# reading video from d:\data\train\collisions\output063.mp4
# reading video from d:\data\train\collisions\output065-26961.mp4
# reading video from d:\data\train\collisions\output066-26961.mp4
# reading video from d:\data\train\collisions\output066-5404.mp4
# reading video from d:\data\train\collisions\output066.mp4
# reading video from d:\data\train\collisions\output067-5404.mp4
# reading video from d:\data\train\collisions\output067.mp4
# reading video from d:\data\train\collisions\output070.mp4
# reading video from d:\data\train\collisions\output071-26961.mp4
# reading video from d:\data\train\collisions\output071.mp4
# reading video from d:\data\train\collisions\output072.mp4
# reading video from d:\data\train\collisions\output073.mp4
# reading video from d:\data\train\collisions\output074-26961.mp4
# reading video from d:\data\train\collisions\output079.mp4
# reading video from d:\data\train\collisions\output083-26961.mp4
# reading video from d:\data\train\collisions\output083.mp4
# reading video from d:\data\train\collisions\output085-26961.mp4
# reading video from d:\data\train\collisions\output086-26961.mp4
# reading video from d:\data\train\collisions\output086.mp4
# reading video from d:\data\train\collisions\output088.mp4
# reading video from d:\data\train\collisions\output089-26961.mp4
# reading video from d:\data\train\collisions\output089.mp4
# reading video from d:\data\train\collisions\output091.mp4
# reading video from d:\data\train\collisions\output092.mp4
# reading video from d:\data\train\collisions\output098.mp4
# reading video from d:\data\train\collisions\output101.mp4
# reading video from d:\data\train\collisions\output107.mp4
# reading video from d:\data\train\collisions\output109.mp4
# reading video from d:\data\train\collisions\output113.mp4
# reading video from d:\data\train\collisions\output116.mp4
# reading video from d:\data\train\collisions\output118.mp4
# reading video from d:\data\train\collisions\output120.mp4
# reading video from d:\data\train\collisions\output122.mp4
# reading video from d:\data\train\collisions\output123.mp4
# reading video from d:\data\train\collisions\output125.mp4
# reading video from d:\data\train\collisions\output127.mp4
# reading video from d:\data\train\collisions\output133.mp4
# reading video from d:\data\val\not-collisions\output004-26961.mp4
# reading video from d:\data\val\not-collisions\output007-5404.mp4
# reading video from d:\data\val\not-collisions\output010-26961.mp4
# reading video from d:\data\val\not-collisions\output014.mp4
# reading video from d:\data\val\not-collisions\output015-26961.mp4
# reading video from d:\data\val\not-collisions\output016-5404.mp4
# reading video from d:\data\val\not-collisions\output023-5404.mp4
# reading video from d:\data\val\not-collisions\output024-27378.mp4
# reading video from d:\data\val\not-collisions\output026-26961.mp4
# reading video from d:\data\val\not-collisions\output028-26961.mp4
# reading video from d:\data\val\not-collisions\output028-5404.mp4
# reading video from d:\data\val\not-collisions\output030-26961.mp4
# reading video from d:\data\val\not-collisions\output030.mp4
# reading video from d:\data\val\not-collisions\output033-26961.mp4
# reading video from d:\data\val\not-collisions\output034-5404.mp4
# reading video from d:\data\val\not-collisions\output037-27378.mp4
# reading video from d:\data\val\not-collisions\output040-26961.mp4
# reading video from d:\data\val\not-collisions\output042-5404.mp4
# reading video from d:\data\val\not-collisions\output043-26961.mp4
# reading video from d:\data\val\not-collisions\output044-26961.mp4
# reading video from d:\data\val\not-collisions\output046.mp4
# reading video from d:\data\val\not-collisions\output047-26961.mp4
# reading video from d:\data\val\not-collisions\output048-5404.mp4
# reading video from d:\data\val\not-collisions\output055-5404.mp4
# reading video from d:\data\val\not-collisions\output061.mp4
# reading video from d:\data\val\not-collisions\output065.mp4
# reading video from d:\data\val\not-collisions\output076-26961.mp4
# reading video from d:\data\val\not-collisions\output078-26961.mp4
# reading video from d:\data\val\not-collisions\output080-26961.mp4
# reading video from d:\data\val\not-collisions\output082.mp4
# reading video from d:\data\val\not-collisions\output087-26961.mp4
# reading video from d:\data\val\not-collisions\output110.mp4
# reading video from d:\data\val\not-collisions\output121.mp4
# reading video from d:\data\val\not-collisions\output128.mp4
# reading video from d:\data\train\not-collisions\output000-5404.mp4
# reading video from d:\data\train\not-collisions\output001-26961.mp4
# reading video from d:\data\train\not-collisions\output001-27378.mp4
# reading video from d:\data\train\not-collisions\output001-5404.mp4
# reading video from d:\data\train\not-collisions\output002-26961.mp4
# reading video from d:\data\train\not-collisions\output002-5404.mp4
# reading video from d:\data\train\not-collisions\output003-26961.mp4
# reading video from d:\data\train\not-collisions\output003.mp4
# reading video from d:\data\train\not-collisions\output004-27378.mp4
# reading video from d:\data\train\not-collisions\output004-5404.mp4
# reading video from d:\data\train\not-collisions\output005-27378.mp4
# reading video from d:\data\train\not-collisions\output005.mp4
# reading video from d:\data\train\not-collisions\output006-5404.mp4
# reading video from d:\data\train\not-collisions\output007-27378.mp4
# reading video from d:\data\train\not-collisions\output008-26961.mp4
# reading video from d:\data\train\not-collisions\output009-27378.mp4
# reading video from d:\data\train\not-collisions\output010-27378.mp4
# reading video from d:\data\train\not-collisions\output010-5404.mp4
# reading video from d:\data\train\not-collisions\output010.mp4
# reading video from d:\data\train\not-collisions\output011-27378.mp4
# reading video from d:\data\train\not-collisions\output012-26961.mp4
# reading video from d:\data\train\not-collisions\output012-27378.mp4
# reading video from d:\data\train\not-collisions\output012-5404.mp4
# reading video from d:\data\train\not-collisions\output014-5404.mp4
# reading video from d:\data\train\not-collisions\output015-27378.mp4
# reading video from d:\data\train\not-collisions\output015-5404.mp4
# reading video from d:\data\train\not-collisions\output016-26961.mp4
# reading video from d:\data\train\not-collisions\output016-27378.mp4
# reading video from d:\data\train\not-collisions\output017-27378.mp4
# reading video from d:\data\train\not-collisions\output018-27378.mp4
# reading video from d:\data\train\not-collisions\output018-5404.mp4
# reading video from d:\data\train\not-collisions\output019-26961.mp4
# reading video from d:\data\train\not-collisions\output019-27378.mp4
# reading video from d:\data\train\not-collisions\output019.mp4
# reading video from d:\data\train\not-collisions\output020-27378.mp4
# reading video from d:\data\train\not-collisions\output020-5404.mp4
# reading video from d:\data\train\not-collisions\output021-27378.mp4
# reading video from d:\data\train\not-collisions\output021.mp4
# reading video from d:\data\train\not-collisions\output022-26961.mp4
# reading video from d:\data\train\not-collisions\output022-27378.mp4
# reading video from d:\data\train\not-collisions\output022.mp4
# reading video from d:\data\train\not-collisions\output023-26961.mp4
# reading video from d:\data\train\not-collisions\output023.mp4
# reading video from d:\data\train\not-collisions\output024-26961.mp4
# reading video from d:\data\train\not-collisions\output025-26961.mp4
# reading video from d:\data\train\not-collisions\output025-27378.mp4
# reading video from d:\data\train\not-collisions\output025-5404.mp4
# reading video from d:\data\train\not-collisions\output025.mp4
# reading video from d:\data\train\not-collisions\output026-27378.mp4
# reading video from d:\data\train\not-collisions\output026-5404.mp4
# reading video from d:\data\train\not-collisions\output026.mp4
# reading video from d:\data\train\not-collisions\output027-27378.mp4
# reading video from d:\data\train\not-collisions\output027.mp4
# reading video from d:\data\train\not-collisions\output028-27378.mp4
# reading video from d:\data\train\not-collisions\output029-26961.mp4
# reading video from d:\data\train\not-collisions\output029-27378.mp4
# reading video from d:\data\train\not-collisions\output029-5404.mp4
# reading video from d:\data\train\not-collisions\output029.mp4
# reading video from d:\data\train\not-collisions\output030-27378.mp4
# reading video from d:\data\train\not-collisions\output031-26961.mp4
# reading video from d:\data\train\not-collisions\output031-27378.mp4
# reading video from d:\data\train\not-collisions\output031-5404.mp4
# reading video from d:\data\train\not-collisions\output031.mp4
# reading video from d:\data\train\not-collisions\output032-27378.mp4
# reading video from d:\data\train\not-collisions\output032.mp4
# reading video from d:\data\train\not-collisions\output033-27378.mp4
# reading video from d:\data\train\not-collisions\output033-5404.mp4
# reading video from d:\data\train\not-collisions\output033.mp4
# reading video from d:\data\train\not-collisions\output034-27378.mp4
# reading video from d:\data\train\not-collisions\output034.mp4
# reading video from d:\data\train\not-collisions\output035-27378.mp4
# reading video from d:\data\train\not-collisions\output035-5404.mp4
# reading video from d:\data\train\not-collisions\output036-26961.mp4
# reading video from d:\data\train\not-collisions\output036-27378.mp4
# reading video from d:\data\train\not-collisions\output036.mp4
# reading video from d:\data\train\not-collisions\output037-5404.mp4
# reading video from d:\data\train\not-collisions\output038-26961.mp4
# reading video from d:\data\train\not-collisions\output038-27378.mp4
# reading video from d:\data\train\not-collisions\output038-5404.mp4
# reading video from d:\data\train\not-collisions\output038.mp4
# reading video from d:\data\train\not-collisions\output039-26961.mp4
# reading video from d:\data\train\not-collisions\output039-5404.mp4
# reading video from d:\data\train\not-collisions\output040-5404.mp4
# reading video from d:\data\train\not-collisions\output042-26961.mp4
# reading video from d:\data\train\not-collisions\output042.mp4
# reading video from d:\data\train\not-collisions\output044-5404.mp4
# reading video from d:\data\train\not-collisions\output044.mp4
# reading video from d:\data\train\not-collisions\output045-5404.mp4
# reading video from d:\data\train\not-collisions\output046-5404.mp4
# reading video from d:\data\train\not-collisions\output047-5404.mp4
# reading video from d:\data\train\not-collisions\output048-26961.mp4
# reading video from d:\data\train\not-collisions\output048.mp4
# reading video from d:\data\train\not-collisions\output049-26961.mp4
# reading video from d:\data\train\not-collisions\output050-26961.mp4
# reading video from d:\data\train\not-collisions\output050.mp4
# reading video from d:\data\train\not-collisions\output051-26961.mp4
# reading video from d:\data\train\not-collisions\output051-5404.mp4
# reading video from d:\data\train\not-collisions\output052-26961.mp4
# reading video from d:\data\train\not-collisions\output052-5404.mp4
# reading video from d:\data\train\not-collisions\output053-26961.mp4
# reading video from d:\data\train\not-collisions\output053-5404.mp4
# reading video from d:\data\train\not-collisions\output053.mp4
# reading video from d:\data\train\not-collisions\output054-5404.mp4
# reading video from d:\data\train\not-collisions\output055.mp4
# reading video from d:\data\train\not-collisions\output056.mp4
# reading video from d:\data\train\not-collisions\output057-26961.mp4
# reading video from d:\data\train\not-collisions\output059-26961.mp4
# reading video from d:\data\train\not-collisions\output059-5404.mp4
# reading video from d:\data\train\not-collisions\output060-26961.mp4
# reading video from d:\data\train\not-collisions\output060.mp4
# reading video from d:\data\train\not-collisions\output064-26961.mp4
# reading video from d:\data\train\not-collisions\output065-5404.mp4
# reading video from d:\data\train\not-collisions\output067-26961.mp4
# reading video from d:\data\train\not-collisions\output068-26961.mp4
# reading video from d:\data\train\not-collisions\output068.mp4
# reading video from d:\data\train\not-collisions\output069-26961.mp4
# reading video from d:\data\train\not-collisions\output069.mp4
# reading video from d:\data\train\not-collisions\output072-26961.mp4
# reading video from d:\data\train\not-collisions\output073-26961.mp4
# reading video from d:\data\train\not-collisions\output075.mp4
# reading video from d:\data\train\not-collisions\output076.mp4
# reading video from d:\data\train\not-collisions\output077-26961.mp4
# reading video from d:\data\train\not-collisions\output077.mp4
# reading video from d:\data\train\not-collisions\output080.mp4
# reading video from d:\data\train\not-collisions\output081-26961.mp4
# reading video from d:\data\train\not-collisions\output081.mp4
# reading video from d:\data\train\not-collisions\output082-26961.mp4
# reading video from d:\data\train\not-collisions\output084-26961.mp4
# reading video from d:\data\train\not-collisions\output084.mp4
# reading video from d:\data\train\not-collisions\output085.mp4
# reading video from d:\data\train\not-collisions\output087.mp4
# reading video from d:\data\train\not-collisions\output088-26961.mp4
# reading video from d:\data\train\not-collisions\output090-26961.mp4
# reading video from d:\data\train\not-collisions\output090.mp4
# reading video from d:\data\train\not-collisions\output091-26961.mp4
# reading video from d:\data\train\not-collisions\output092-26961.mp4
# reading video from d:\data\train\not-collisions\output093.mp4
# reading video from d:\data\train\not-collisions\output095.mp4
# reading video from d:\data\train\not-collisions\output096.mp4
# reading video from d:\data\train\not-collisions\output097.mp4
# reading video from d:\data\train\not-collisions\output099.mp4
# reading video from d:\data\train\not-collisions\output100.mp4
# reading video from d:\data\train\not-collisions\output102.mp4
# reading video from d:\data\train\not-collisions\output103.mp4
# reading video from d:\data\train\not-collisions\output104.mp4
# reading video from d:\data\train\not-collisions\output105.mp4
# reading video from d:\data\train\not-collisions\output106.mp4
# reading video from d:\data\train\not-collisions\output112.mp4
# reading video from d:\data\train\not-collisions\output114.mp4
# reading video from d:\data\train\not-collisions\output115.mp4
# reading video from d:\data\train\not-collisions\output117.mp4
# reading video from d:\data\train\not-collisions\output119.mp4
# reading video from d:\data\train\not-collisions\output124.mp4
# reading video from d:\data\train\not-collisions\output126.mp4
# reading video from d:\data\train\not-collisions\output129.mp4
# reading video from d:\data\train\not-collisions\output130.mp4
# reading video from d:\data\train\not-collisions\output134.mp4
# reading video from d:\data\train\not-collisions\output135.mp4
# reading video from d:\data\val\collisions\output004.mp4
# reading video from d:\data\val\collisions\output005-26961.mp4
# reading video from d:\data\val\collisions\output007-26961.mp4
# reading video from d:\data\val\collisions\output007.mp4
# reading video from d:\data\val\collisions\output013.mp4
# reading video from d:\data\val\collisions\output015.mp4
# reading video from d:\data\val\collisions\output018-26961.mp4
# reading video from d:\data\val\collisions\output028.mp4
# reading video from d:\data\val\collisions\output035-26961.mp4
# reading video from d:\data\val\collisions\output041-26961.mp4
# reading video from d:\data\val\collisions\output041-5404.mp4
# reading video from d:\data\val\collisions\output043-5404.mp4
# reading video from d:\data\val\collisions\output046-26961.mp4
# reading video from d:\data\val\collisions\output049-5404.mp4
# reading video from d:\data\val\collisions\output057-5404.mp4
# reading video from d:\data\val\collisions\output058-26961.mp4
# reading video from d:\data\val\collisions\output064-5404.mp4
# reading video from d:\data\val\collisions\output064.mp4
# reading video from d:\data\val\collisions\output070-26961.mp4
# reading video from d:\data\val\collisions\output074.mp4
# reading video from d:\data\val\collisions\output075-26961.mp4
# reading video from d:\data\val\collisions\output079-26961.mp4
# reading video from d:\data\val\collisions\output094.mp4
# reading video from d:\data\val\collisions\output108.mp4
# reading video from d:\data\val\collisions\output111.mp4
# reading video from d:\data\val\collisions\output132.mp4

# %% [markdown]
# ## Store videos on disk as np-arrays

# %%
# which ones do not have a numpy representation computed yet? i.e. no .npy file present
to_process = videos \
                | where( lambda f: not isfile( f[1].replace('.mp4','.videos.npy') ) )
to_process_withvideo = adornVideo( to_process )
videos_withvideo =  adornVideo( videos )

v = videos_withvideo | take(5) | select(lambda v: v[2].shape) |  as_list()

print(v)

# some assertions, apparently we are not getting the video size we require
for shape in v:
    assert( shape[2]==video_size and shape[1]==video_size )
# Out:
# reading video from d:\data\train\collisions\output000-26961.mp4
# reading video from d:\data\train\collisions\output000.mp4
# reading video from d:\data\train\collisions\output001.mp4
# reading video from d:\data\train\collisions\output002-27378.mp4
# reading video from d:\data\train\collisions\output002.mp4
# reading video from d:\data\train\collisions\output003-27378.mp4
# [(113, 64, 64, 3), (60, 64, 64, 3), (68, 64, 64, 3), (125, 64, 64, 3), (38, 64, 64, 3)]

# %%
# write these npy files out to the file system in the respective location
for v in to_process_withvideo:
    print( 'saved %s (class %d)' % ( v[1], v[0] ) )
    np.save(v[1].replace('.mp4','.videos.npy'), v[2])
# Out:
# reading video from d:\data\train\collisions\output000-26961.mp4
# saved d:\data\train\collisions\output000-26961.mp4 (class 1)
# reading video from d:\data\train\collisions\output000.mp4
# saved d:\data\train\collisions\output000.mp4 (class 1)
# reading video from d:\data\train\collisions\output001.mp4
# saved d:\data\train\collisions\output001.mp4 (class 1)
# reading video from d:\data\train\collisions\output002-27378.mp4
# saved d:\data\train\collisions\output002-27378.mp4 (class 1)
# reading video from d:\data\train\collisions\output002.mp4
# saved d:\data\train\collisions\output002.mp4 (class 1)
# reading video from d:\data\train\collisions\output003-27378.mp4
# saved d:\data\train\collisions\output003-27378.mp4 (class 1)
# reading video from d:\data\train\collisions\output003-5404.mp4
# saved d:\data\train\collisions\output003-5404.mp4 (class 1)
# reading video from d:\data\train\collisions\output003.mp4
# saved d:\data\train\collisions\output003.mp4 (class 1)
# reading video from d:\data\train\collisions\output005-5404.mp4
# saved d:\data\train\collisions\output005-5404.mp4 (class 1)
# reading video from d:\data\train\collisions\output005.mp4
# saved d:\data\train\collisions\output005.mp4 (class 1)
# reading video from d:\data\train\collisions\output006-26961.mp4
# saved d:\data\train\collisions\output006-26961.mp4 (class 1)
# reading video from d:\data\train\collisions\output006-27378.mp4
# saved d:\data\train\collisions\output006-27378.mp4 (class 1)

# %% [markdown]
# ok, so at this point we now have a numpy array for every single video file! the numpy arrays are fixed on some video size, length and frame rate i.e. 200^2, 5 seconds and 25fps.

# %% [markdown]
# ## Keras model on optical flow only

# %%
import keras

def npy_flow_from_directory( 
    colpath='collisions',
    noncolpath='not-collisions',
    ext='.npy'):
    # get a shuffled infinite sequence of training files
    files = GetFiles(join(base_dir,colpath), label=1, ext=ext) \
        | chain_with( GetFiles(join(base_dir,noncolpath), label=0, ext=ext) ) \
        | as_list() \
        | pshuffle() \
        | pcycle()

    # clever stuff here, the actual video will be loaded lazily
    files_withdata = files \
        | select( lambda f: f + ( np.load(f[1]) ,) )

    for x in files_withdata:
          yield x

# %%
max_frames = videos | select(lambda x : x[1].replace('.mp4','.flows.npy')) \
           | select(lambda x : np.load(x)) \
           | select(lambda x : x.shape[0]) | max()
print(max_frames)
# Out:
# 124

# %%
maxs = videos | select(lambda x : x[1].replace('.mp4','.flows.npy')) \
           | select(lambda x : np.load(x)) \
           | select(lambda x : x.max(axis=(0,1))) | as_npy
#print(maxs)
mins,maxs,avgs = maxs.min(axis=0),maxs.max(axis=0),np.average(maxs,axis=0)
print(mins,maxs,avgs)
ang_diap = (mins[0],avgs[0])
mag_diap = (mins[1],maxs[1])
# Out:
# [5385.           9.7244805] [9.00000000e+04 1.14075761e+01] [4.19840879e+04 1.10563428e+01]

# %%
def zero_pad(x):
    return np.pad(x,[(0,max_frames-x.shape[0]),(0,0),(0,0)],'constant',constant_values=[(0,0),(0,0),(0,0)])

@Pipe
def zero_pad_flow(flow):
    for x in flow:
        yield x[0],x[1],zero_pad(x[2])
        
@Pipe
def extend_channel(flow):
    for x in flow:
        yield x[0],x[1],x[2].reshape(x[2].shape[0],x[2].shape[1],1)
        
@Pipe
def normalize(flow):
    for x in flow:
        x2 = x[2]
        x2[:,:,0] = (x2[:,:,0]-ang_diap[0]) / (ang_diap[1]-ang_diap[0])
        x2[:,:,1] = (x2[:,:,1]-mag_diap[0]) / (mag_diap[0]-mag_diap[1])
        yield x[0],x[1],x2

# %%
train_flow = npy_flow_from_directory(colpath='train/collisions',noncolpath='train/not-collisions',ext='.flows.npy') \
            | zero_pad_flow | normalize()
val_flow = npy_flow_from_directory(colpath='val/collisions',noncolpath='val/not-collisions',ext='.flows.npy') \
            | zero_pad_flow | normalize()

# %%
train_flow | take(1) | select (lambda x: x[2].shape) | as_list
# Out:
# [(124, 100, 2)]

# %%
ims = train_flow | take(5) | select (lambda x: x[2])
fig, ax = plt.subplots(5,4,figsize=(6,6))
for i,x in enumerate(ims):
    ax[i,0].imshow(x[:,:,0])
    ax[i,1].imshow(x[:,:,1])
    ax[i,2].plot(x[0,:,0])
    ax[i,3].plot(x[0,:,1])
plt.tight_layout()
plt.show()

# %%
batchsize = 20
bins = 100

@Pipe
def to_batches(flow, batchsize=batchsize):
    while(True):
        batch = np.zeros( (batchsize, max_frames, bins, 2 ) )
        labels = np.zeros( (batchsize,1))
        for i in range(batchsize):
            data = next(flow)
            batch[i] = data[2]
            labels[i] = data[0]
        yield ( batch, labels )

# %%
from keras import layers
from keras import models
from keras import optimizers

model = models.Sequential()
model.add(layers.AveragePooling2D((2, 2),input_shape=(max_frames, bins, 2)))
model.add(layers.Conv2D(8, (3, 3), data_format='channels_last',activation='relu',kernel_initializer='glorot_uniform'))
model.add(layers.AveragePooling2D((2, 2)))
model.add(layers.Conv2D(16, (3, 3) ,activation='relu',kernel_initializer='glorot_uniform'))
model.add(layers.AveragePooling2D((2, 2)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.1))
model.add(layers.Dense(100,activation='relu',kernel_initializer='glorot_uniform'))
model.add(layers.Dense(1, activation='sigmoid',kernel_initializer='glorot_uniform'))
model.compile(loss='binary_crossentropy',
              #optimizer=optimizers.Nadam(lr=0.005),
              optimizer=optimizers.adam(),
              metrics=['acc'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# average_pooling2d_15 (Averag (None, 62, 50, 2)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 60, 48, 8)         152
# _________________________________________________________________
# average_pooling2d_16 (Averag (None, 30, 24, 8)         0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 28, 22, 16)        1168
# _________________________________________________________________
# average_pooling2d_17 (Averag (None, 14, 11, 16)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 2464)              0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 2464)              0
# _________________________________________________________________
# dense_11 (Dense)             (None, 100)               246500
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 101
# =================================================================
# Total params: 247,921
# Trainable params: 247,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit_generator(
      train_flow | to_batches,
      steps_per_epoch=100, 
      validation_data=val_flow | to_batches,
      use_multiprocessing=False, # has to be false on windows..
      validation_steps = 10,
      epochs=30)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 3s 26ms/step - loss: 0.6133 - acc: 0.6610 - val_loss: 0.6597 - val_acc: 0.6600
# Epoch 2/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.4364 - acc: 0.7875 - val_loss: 0.7845 - val_acc: 0.6300
# Epoch 3/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.3250 - acc: 0.8620 - val_loss: 1.0270 - val_acc: 0.6300
# Epoch 4/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.2481 - acc: 0.9010 - val_loss: 0.9636 - val_acc: 0.6700
# Epoch 5/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.1766 - acc: 0.9315 - val_loss: 1.2497 - val_acc: 0.6450
# Epoch 6/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0959 - acc: 0.9720 - val_loss: 1.5762 - val_acc: 0.6850
# Epoch 7/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0660 - acc: 0.9810 - val_loss: 1.5565 - val_acc: 0.7150
# Epoch 8/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0369 - acc: 0.9945 - val_loss: 1.6951 - val_acc: 0.7150
# Epoch 9/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0246 - acc: 0.9960 - val_loss: 1.7889 - val_acc: 0.6850
# Epoch 10/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0274 - acc: 0.9940 - val_loss: 1.9659 - val_acc: 0.6850
# Epoch 11/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0167 - acc: 0.9975 - val_loss: 2.2144 - val_acc: 0.6950
# Epoch 12/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0205 - acc: 0.9935 - val_loss: 2.3360 - val_acc: 0.6900
# Epoch 13/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0405 - acc: 0.9880 - val_loss: 2.4960 - val_acc: 0.6150
# Epoch 14/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0092 - acc: 0.9995 - val_loss: 2.4350 - val_acc: 0.6650
# Epoch 15/30
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0071 - acc: 0.9995 - val_loss: 2.7818 - val_acc: 0.6350
# Epoch 16/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0034 - acc: 1.0000 - val_loss: 2.5283 - val_acc: 0.6500
# Epoch 17/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0051 - acc: 0.9995 - val_loss: 2.4630 - val_acc: 0.6850
# Epoch 18/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0031 - acc: 1.0000 - val_loss: 2.9099 - val_acc: 0.6500
# Epoch 19/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0019 - acc: 1.0000 - val_loss: 2.6358 - val_acc: 0.6800
# Epoch 20/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0020 - acc: 1.0000 - val_loss: 2.6668 - val_acc: 0.6800
# Epoch 21/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0022 - acc: 1.0000 - val_loss: 3.0690 - val_acc: 0.6350
# Epoch 22/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0022 - acc: 0.9995 - val_loss: 2.8024 - val_acc: 0.6650
# Epoch 23/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0046 - acc: 0.9995 - val_loss: 2.4562 - val_acc: 0.6350
# Epoch 24/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0435 - acc: 0.9855 - val_loss: 2.7496 - val_acc: 0.6350
# Epoch 25/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0054 - acc: 0.9995 - val_loss: 2.5841 - val_acc: 0.6300
# Epoch 26/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0033 - acc: 1.0000 - val_loss: 2.6518 - val_acc: 0.6850
# Epoch 27/30
# 100/100 [==============================] - 2s 21ms/step - loss: 0.0154 - acc: 0.9965 - val_loss: 3.1244 - val_acc: 0.5650
# Epoch 28/30
# 100/100 [==============================] - 2s 22ms/step - loss: 0.0025 - acc: 1.0000 - val_loss: 2.7974 - val_acc: 0.6300
# Epoch 29/30
# 100/100 [==============================] - 2s 22ms/step - loss: 9.0707e-04 - acc: 1.0000 - val_loss: 2.7721 - val_acc: 0.6700
# Epoch 30/30
# 100/100 [==============================] - 2s 22ms/step - loss: 8.7374e-04 - acc: 1.0000 - val_loss: 3.1965 - val_acc: 0.6350

# %%
def plotHistory(history):
        plt.plot(history.history['acc'])
        plt.plot(history.history['val_acc'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xticks(range(0,50,10))
        #plt.yticks(range(0,1,0.1))
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper left')
        plt.show()
plotHistory(hist)

# %% [markdown]
# ## Video Augmentation

# %% [markdown]
# For every single video file, we compute a random augmentation consistently across all of the frames

# %%
import keras
from keras.preprocessing.image import ImageDataGenerator

data_gen_args = dict(featurewise_center=False,
                     featurewise_std_normalization=False,
                     rotation_range=10,
                     width_shift_range=0.1,
                     height_shift_range=0.1,
                     zoom_range=0.2,
                     horizontal_flip=True)

image_datagen = ImageDataGenerator(**data_gen_args)

def videoFlowWithAugmentation( 
    colpath='collisions',
    noncolpath='not-collisions',
    augment=True, 
    diff=False,
    normalize=True):
    # get a shuffled infinite sequence of training videos
    videos = GetVideos(join(base_dir,colpath), label=1, ext='.npy') \
        | chain_with( GetVideos(join(base_dir,noncolpath), label=0, ext='.npy') ) \
        | as_list() \
        | pshuffle() \
        | pcycle()

    # clever stuff here, the actual video will be loaded lazily
    videos_withdata = videos \
        | select( lambda f: f + ( np.load(f[1]) ,) )

    for video in videos_withdata:
        # for every frame in this video generate the same transformation
        # and yield it all back in sequence order
        trans = image_datagen.get_random_transform(video[2].shape)
        augmentedVideo = np.zeros( video[2].shape )
        for i in range(video[2].shape[0]):
            if augment:
                augmentedVideo[i] = image_datagen.apply_transform(video[2][i], trans)
            else:
                augmentedVideo[i] = video[2][i]
            
            # now is a good time to transform the video onto 0-1
            # we need to do this to get convergence when we train i.e. homogenise features
            if normalize:
                augmentedVideo[i] = augmentedVideo[i] / 255
            
            # take xth order differences of frames to convey pixel-wise temporal changes
            if diff is not None:
                augmentedVideo[i, 0:augmentedVideo[i].shape[0]-diff] = np.diff(augmentedVideo[i], axis=0, n=diff)
            
        yield video[:-1] + (augmentedVideo,)
            
train_flow = videoFlowWithAugmentation(colpath='train/collisions',noncolpath='train/not-collisions', diff=None)
# remember, on validation we don't want to augment anything!
val_flow = videoFlowWithAugmentation(colpath='val/collisions',noncolpath='val/not-collisions', augment=False)
# Out:
# C:\Anaconda\envs\py35\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import keras
print(keras.__version__)
# Out:
# 2.2.2

# %% [markdown]
# let's visualize the augmented results for this video

# %%
def getTestImages(flow, howmany=5):
    augmentedVideo = next(flow)
    print(augmentedVideo[2].shape)
    return range(augmentedVideo[2].shape[0]) \
        | select( lambda i: augmentedVideo[2][i] ) \
        | take(howmany)

# show some augmented train images
images = getTestImages(train_flow)
for x in range(2):
    images = images | chain_with( getTestImages(train_flow) )

show_images( images | as_list, cols=4 )

# and do the same for some validation images
images = getTestImages(val_flow)
for x in range(2):
    images = images | chain_with( getTestImages(val_flow) )

show_images( images | as_list, cols=4 )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-9ee4e8480817> in <module>()
#       5
#       6 # show some augmented train images
# ----> 7 images = getTestImages(train_flow)
#       8 for x in range(2):
#       9     images = images | chain_with( getTestImages(train_flow) )
#
# <ipython-input-7-9ee4e8480817> in getTestImages(flow, howmany)
#       1 def getTestImages(flow, howmany=5):
# ----> 2     augmentedVideo = next(flow)
#       3     print(augmentedVideo[2].shape)
#       4     return range(augmentedVideo[2].shape[0])         | select( lambda i: augmentedVideo[2][i] )         | take(howmany)
#       5
#
# <ipython-input-5-4e04e538c9d5> in videoFlowWithAugmentation(colpath, noncolpath, augment, diff, normalize)
#      31         for i in range(video[2].shape[0]):
#      32             if augment:
# ---> 33                 augmentedVideo[i] = image_datagen.apply_transform(video[2][i], trans)
#      34             else:
#      35                 augmentedVideo[i] = video[2][i]
#
# C:\Anaconda\envs\py35\lib\site-packages\keras_preprocessing\image.py in apply_transform(self, x, transform_parameters)
#    1141                                    row_axis=img_row_axis, col_axis=img_col_axis,
#    1142                                    channel_axis=img_channel_axis,
# -> 1143                                    fill_mode=self.fill_mode, cval=self.cval)
#    1144
#    1145         if transform_parameters.get('channel_shift_intensity') is not None:
#
# C:\Anaconda\envs\py35\lib\site-packages\keras_preprocessing\image.py in apply_affine_transform(x, theta, tx, ty, shear, zx, zy, row_axis, col_axis, channel_axis, fill_mode, cval)
#     320
#     321     if transform_matrix is not None:
# --> 322         h, w = x.shape[row_axis], x.shape[col_axis]
#     323         transform_matrix = transform_matrix_offset_center(
#     324             transform_matrix, h, w)
#
# IndexError: tuple index out of range

# %% [markdown]
# ok this is looking pretty good, next thing is to zeropad so that the number of frames is always the same i.e. max seconds * framerate

# %%
def zeroPadVideos(videoStream):
    for video in videoStream:
        zeroPadded = np.zeros( ( max_length * framerate, video_size, video_size, 3 ) )
        zeroPadded[ 0:video[2].shape[0], :, : ,: ] = video[2]
        yield video[:-1] + (zeroPadded,)

# %%
def getVectorFlowHistogramsForStream( videoStream ):
    for video in videoStream:
        
        histogram = np.zeros( 20 )
        
        for frame in range(video)
        
        # do code to compute the 
        
        yield histogram
# Out:
#   File "<ipython-input-39-6e8e1a0c91dd>", line 1
#     def getVectorFlowHistogramsForStream( videoStream ):
#                                                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# let's check that the framerate is indeed fixed

# %%
for x in range(3):
    assert( next( zeroPadVideos( train_flow ) )[2].shape[0]==max_length * framerate )

# %% [markdown]
# OK the next problem is we have a nice generator for videos, but we are doing a 4d CNN with videos and need a batch dimension, so let's write another generator which will batch X videos at a time
#
# ```
# next( zeroPadVideos( flow ) )[3].shape
# ```
# == (125, 200, 200, 3)

# %%
def getBatchVideosFlow(flow, batchsize):
    while(True):
        batch = np.zeros( (batchsize, max_length * framerate, video_size, video_size, 3 ) )
        labels = np.zeros( (batchsize,1))
        for i in range(batchsize):
            video = next( zeroPadVideos( flow ) )
            batch[i] = video[2]
            labels[i] = video[0]
        yield ( batch, labels )

# %% [markdown]
# We now have a generator giving us batches of training examples and respective labels, we can feed this into keras fit_generator!

# %%
from sys import getsizeof

r = next( getBatchVideosFlow( train_flow, 20 ) )
print(r[0].shape)
print(r[1].shape)

getsizeof(r[0])/1024**3
# == 2.4gb for 20 videos of 125 frames @ 200^2*3
# Out:
# (20, 125, 64, 64, 3)
# (20, 1)
# 0.22888198494911194

# %% [markdown]
# now let's try and train keras on it

# %%
from keras import layers
from keras import models
from keras import regularizers

prelu = layers.advanced_activations.LeakyReLU(alpha=0.3)

model = models.Sequential()
model.add(layers.Conv3D(15, (1, 3, 3),
                        input_shape=(max_length * framerate, video_size, video_size, 3)))
model.add(prelu)
model.add(layers.AveragePooling3D((4, 2, 2)))
model.add(layers.Conv3D(32, (2, 3, 3) ))
model.add(prelu)
model.add(layers.AveragePooling3D((5, 2, 2)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(20))
model.add(prelu)
model.add(layers.Dense(20))
model.add(prelu)
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_146 (Conv3D)          (None, 50, 46, 46, 15)    420
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   multiple                  0
# _________________________________________________________________
# average_pooling3d_8 (Average (None, 12, 23, 23, 15)    0
# _________________________________________________________________
# conv3d_147 (Conv3D)          (None, 11, 21, 21, 32)    8672
# _________________________________________________________________
# average_pooling3d_9 (Average (None, 2, 10, 10, 32)     0
# _________________________________________________________________
# flatten_67 (Flatten)         (None, 6400)              0
# _________________________________________________________________
# dropout_60 (Dropout)         (None, 6400)              0
# _________________________________________________________________
# dense_216 (Dense)            (None, 20)                128020
# _________________________________________________________________
# dense_217 (Dense)            (None, 20)                420
# _________________________________________________________________
# dense_218 (Dense)            (None, 1)                 21
# =================================================================
# Total params: 137,553
# Trainable params: 137,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers

diff_val = None

train_flow = videoFlowWithAugmentation(colpath='./train/collisions',noncolpath='./train/not-collisions', augment=True, diff=diff_val)
# remember, on validation we don't want to augment anything!
val_flow = videoFlowWithAugmentation(colpath='./val/collisions',noncolpath='./val/not-collisions', augment=False, diff=diff_val)

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Nadam(lr=0.005),
              metrics=['acc'])

print('training with videosize: %s framerate: %d' % (video_size, framerate))

history = model.fit_generator(
      getBatchVideosFlow( train_flow, 20 ),
      steps_per_epoch=9, 
      validation_data=getBatchVideosFlow( val_flow, 10 ), 
      # has to be false on windows..
      use_multiprocessing=False, 
      validation_steps = 8,
      epochs=30)
# Out:
# training with videosize: 48 framerate: 10
# Epoch 1/30
# 9/9 [==============================] - 5s 582ms/step - loss: 1.0420 - acc: 0.6056 - val_loss: 0.6862 - val_acc: 0.6500
# Epoch 2/30
# 9/9 [==============================] - 4s 463ms/step - loss: 0.6548 - acc: 0.6444 - val_loss: 0.6772 - val_acc: 0.6375
# Epoch 3/30
# 9/9 [==============================] - 5s 504ms/step - loss: 0.7260 - acc: 0.6056 - val_loss: 0.6650 - val_acc: 0.7250
# Epoch 4/30
# 9/9 [==============================] - 5s 514ms/step - loss: 0.6504 - acc: 0.6500 - val_loss: 0.7478 - val_acc: 0.4875
# Epoch 5/30
# 9/9 [==============================] - 5s 506ms/step - loss: 0.6437 - acc: 0.6167 - val_loss: 0.6660 - val_acc: 0.6750
# Epoch 6/30
# 9/9 [==============================] - 4s 500ms/step - loss: 0.6253 - acc: 0.6389 - val_loss: 0.7026 - val_acc: 0.5125
# Epoch 7/30
# 9/9 [==============================] - 5s 511ms/step - loss: 0.6178 - acc: 0.6222 - val_loss: 0.7003 - val_acc: 0.4875
# Epoch 8/30
# 9/9 [==============================] - 5s 519ms/step - loss: 0.6278 - acc: 0.6389 - val_loss: 0.7063 - val_acc: 0.4750
# Epoch 9/30
# 9/9 [==============================] - 5s 518ms/step - loss: 0.6408 - acc: 0.6222 - val_loss: 0.6774 - val_acc: 0.6500
# Epoch 10/30
# 9/9 [==============================] - 5s 502ms/step - loss: 0.5882 - acc: 0.6389 - val_loss: 0.7718 - val_acc: 0.4625
# Epoch 11/30
# 9/9 [==============================] - 5s 506ms/step - loss: 0.6096 - acc: 0.6611 - val_loss: 0.7552 - val_acc: 0.4625
# Epoch 12/30
# 9/9 [==============================] - 5s 514ms/step - loss: 0.6011 - acc: 0.6500 - val_loss: 0.7247 - val_acc: 0.5000
# Epoch 13/30
# 9/9 [==============================] - 5s 509ms/step - loss: 0.6325 - acc: 0.6889 - val_loss: 0.7197 - val_acc: 0.4875
# Epoch 14/30
# 9/9 [==============================] - 4s 497ms/step - loss: 0.6497 - acc: 0.6111 - val_loss: 0.6920 - val_acc: 0.5500
# Epoch 15/30
# 9/9 [==============================] - 5s 512ms/step - loss: 0.6514 - acc: 0.6389 - val_loss: 0.7590 - val_acc: 0.4625
# Epoch 16/30
# 9/9 [==============================] - 5s 517ms/step - loss: 0.6302 - acc: 0.5722 - val_loss: 0.7362 - val_acc: 0.5000
# Epoch 17/30
# 9/9 [==============================] - 5s 530ms/step - loss: 0.7707 - acc: 0.5833 - val_loss: 0.8477 - val_acc: 0.4750
# Epoch 18/30
# 9/9 [==============================] - 4s 500ms/step - loss: 0.7557 - acc: 0.5889 - val_loss: 0.6978 - val_acc: 0.6000
# Epoch 19/30
# 9/9 [==============================] - 5s 509ms/step - loss: 0.6212 - acc: 0.6389 - val_loss: 0.6867 - val_acc: 0.5875
# Epoch 20/30
# 9/9 [==============================] - 5s 517ms/step - loss: 0.6655 - acc: 0.5833 - val_loss: 0.7975 - val_acc: 0.4750
# Epoch 21/30
# 9/9 [==============================] - 5s 506ms/step - loss: 0.6005 - acc: 0.6833 - val_loss: 0.7474 - val_acc: 0.4500
# Epoch 22/30
# 9/9 [==============================] - 4s 497ms/step - loss: 0.5754 - acc: 0.6111 - val_loss: 0.7926 - val_acc: 0.5000
# Epoch 23/30
# 9/9 [==============================] - 5s 513ms/step - loss: 0.5937 - acc: 0.6333 - val_loss: 0.7323 - val_acc: 0.5125
# Epoch 24/30
# 9/9 [==============================] - 5s 519ms/step - loss: 0.6057 - acc: 0.6111 - val_loss: 0.7017 - val_acc: 0.5125
# Epoch 25/30
# 9/9 [==============================] - 5s 516ms/step - loss: 0.5423 - acc: 0.7167 - val_loss: 0.8763 - val_acc: 0.5125
# Epoch 26/30
# 9/9 [==============================] - 5s 510ms/step - loss: 0.6290 - acc: 0.6500 - val_loss: 1.1738 - val_acc: 0.4750
# Epoch 27/30
# 9/9 [==============================] - 5s 540ms/step - loss: 0.6075 - acc: 0.6667 - val_loss: 0.7139 - val_acc: 0.5750
# Epoch 28/30
# 9/9 [==============================] - 5s 525ms/step - loss: 0.5484 - acc: 0.7000 - val_loss: 0.6993 - val_acc: 0.6000
# Epoch 29/30
# 9/9 [==============================] - 5s 505ms/step - loss: 0.5279 - acc: 0.6778 - val_loss: 0.9308 - val_acc: 0.4500
# Epoch 30/30
# 9/9 [==============================] - 4s 497ms/step - loss: 0.5613 - acc: 0.6722 - val_loss: 0.8587 - val_acc: 0.5250

# %% [markdown]
# Now we plot to see the convergence behaviour and overfitting

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']


f, (ax1,ax2) = plt.subplots(2,1)

epochs = range(len(acc))

ax1.plot(epochs, acc, 'bo', label='Training acc')
ax1.plot(epochs, val_acc, 'b', label='Validation acc')
ax1.set_title('Training and validation accuracy')
ax1.legend()


ax2.plot(epochs, loss, 'bo', label='Training loss')
ax2.plot(epochs, val_loss, 'b', label='Validation loss')
ax2.set_title('Training and validation loss')
ax2.legend()

plt.show()

# %% [markdown]
# lets try using conv base as an input now

# %%
from keras.applications import VGG16

conv_base = VGG16(weights='imagenet',
                  include_top=False,
                  input_shape=(video_size, video_size, 3))

conv_base.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# add the conv base into a basic classifier
#
# Lets write a new generator which will give us embeddings of the frames in 2 dimensions

# %%
from keras import optimizers
from functools import reduce

def getBatchVideoEmbeddingsFlow(flow, batchsize, color_channel=None):
    while(True):
        oshape = (batchsize, max_length * framerate, reduce(mul, conv_base.output_shape[1:]) )
        if color_channel is True: oshape = oshape + (1,)
            
        batch = np.zeros( oshape )
        labels = np.zeros( (batchsize,1))
        for i in range(batchsize):
            video = next(zeroPadVideos( flow ))
            embedding = conv_base.predict( video[2] )
            embedding = embedding.reshape(oshape[1:])
            batch[i] = embedding
            labels[i] = video[0]
        yield ( batch, labels )

# %% [markdown]
# We can visualise the results

# %%
train_flow = videoFlowWithAugmentation(colpath='./train/collisions',noncolpath='./train/not-collisions', augment=False, diff=False)
batch = next(getBatchVideoEmbeddingsFlow(train_flow,20))


show_images( range(10) | select( lambda i: batch[0][i] ) | as_list, cols=4 )

# %% [markdown]
# now let's build a simple 2d cnn to take these as inputs

# %%
from keras import layers
from keras import models

model = models.Sequential()
model.add(layers.Conv2D(30, (3,1), activation='relu',
                        input_shape=(max_length * framerate, reduce(mul, conv_base.output_shape[1:]), 1)))
model.add(layers.AveragePooling2D((2,2)))
model.add(layers.Conv2D(64, (3,2), activation='relu'))
model.add(layers.AveragePooling2D((2,10)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(10, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_107 (Conv2D)          (None, 123, 2048, 30)     120
# _________________________________________________________________
# average_pooling2d_11 (Averag (None, 61, 1024, 30)      0
# _________________________________________________________________
# conv2d_108 (Conv2D)          (None, 59, 1023, 64)      11584
# _________________________________________________________________
# average_pooling2d_12 (Averag (None, 29, 102, 64)       0
# _________________________________________________________________
# flatten_142 (Flatten)        (None, 189312)            0
# _________________________________________________________________
# dropout_128 (Dropout)        (None, 189312)            0
# _________________________________________________________________
# dense_464 (Dense)            (None, 10)                1893130
# _________________________________________________________________
# dense_465 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_466 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 1,904,955
# Trainable params: 1,904,955
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Nadam(lr=0.005),
              metrics=['acc'])

print('training with videosize: %s framerate: %d' % (video_size, framerate))

train_flow = videoFlowWithAugmentation(colpath='./train/collisions',noncolpath='./train/not-collisions', augment=True, diff=diff_val)
# remember, on validation we don't want to augment anything!
val_flow = videoFlowWithAugmentation(colpath='./val/collisions',noncolpath='./val/not-collisions', augment=False, diff=diff_val)

history = model.fit_generator(
      getBatchVideoEmbeddingsFlow(train_flow,10, color_channel=True),
      steps_per_epoch=18, 
      validation_data=getBatchVideoEmbeddingsFlow( val_flow, 10, color_channel=True ), 
      # has to be false on windows..
      use_multiprocessing=False, 
      validation_steps = 8,
      epochs=100)
# Out:
# training with videosize: 64 framerate: 25
# Epoch 1/100
# 18/18 [==============================] - 44s 2s/step - loss: 5.7608 - acc: 0.6000 - val_loss: 8.4620 - val_acc: 0.4750
# Epoch 2/100
# 18/18 [==============================] - 31s 2s/step - loss: 5.9100 - acc: 0.6333 - val_loss: 8.6635 - val_acc: 0.4625
# Epoch 3/100
# 18/18 [==============================] - 31s 2s/step - loss: 6.4571 - acc: 0.5833 - val_loss: 6.1819 - val_acc: 0.5125
# Epoch 4/100
# 18/18 [==============================] - 30s 2s/step - loss: 1.4982 - acc: 0.5667 - val_loss: 0.7055 - val_acc: 0.4750
# Epoch 5/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6723 - acc: 0.6111 - val_loss: 0.7138 - val_acc: 0.5000
# Epoch 6/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6776 - acc: 0.6167 - val_loss: 0.7127 - val_acc: 0.5000
# Epoch 7/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6724 - acc: 0.6167 - val_loss: 0.7196 - val_acc: 0.4875
# Epoch 8/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6628 - acc: 0.6278 - val_loss: 0.7218 - val_acc: 0.5000
# Epoch 9/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6679 - acc: 0.6167 - val_loss: 0.7229 - val_acc: 0.5000
# Epoch 10/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.7082 - acc: 0.5944 - val_loss: 0.7190 - val_acc: 0.4750
# Epoch 11/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6683 - acc: 0.6278 - val_loss: 0.7145 - val_acc: 0.5000
# Epoch 12/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6719 - acc: 0.6056 - val_loss: 0.7267 - val_acc: 0.4750
# Epoch 13/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6663 - acc: 0.6222 - val_loss: 0.7249 - val_acc: 0.4875
# Epoch 14/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6716 - acc: 0.6056 - val_loss: 0.7238 - val_acc: 0.4875
# Epoch 15/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6616 - acc: 0.6222 - val_loss: 0.7336 - val_acc: 0.4750
# Epoch 16/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6720 - acc: 0.6111 - val_loss: 0.7349 - val_acc: 0.4625
# Epoch 17/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6628 - acc: 0.6278 - val_loss: 0.7316 - val_acc: 0.4750
# Epoch 18/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6708 - acc: 0.6000 - val_loss: 0.7285 - val_acc: 0.4750
# Epoch 19/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6558 - acc: 0.6389 - val_loss: 0.7374 - val_acc: 0.4750
# Epoch 20/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6776 - acc: 0.6056 - val_loss: 0.7259 - val_acc: 0.4875
# Epoch 21/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6692 - acc: 0.6111 - val_loss: 0.7294 - val_acc: 0.4750
# Epoch 22/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6607 - acc: 0.6278 - val_loss: 0.7336 - val_acc: 0.4750
# Epoch 23/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6753 - acc: 0.5944 - val_loss: 0.7340 - val_acc: 0.4625
# Epoch 24/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6627 - acc: 0.6278 - val_loss: 0.7320 - val_acc: 0.4750
# Epoch 25/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6759 - acc: 0.6000 - val_loss: 0.7228 - val_acc: 0.4750
# Epoch 26/100
# 18/18 [==============================] - 29s 2s/step - loss: 0.6596 - acc: 0.6333 - val_loss: 0.7375 - val_acc: 0.4750
# Epoch 27/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6704 - acc: 0.6056 - val_loss: 0.7227 - val_acc: 0.4875
# Epoch 28/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6744 - acc: 0.6167 - val_loss: 0.7240 - val_acc: 0.4875
# Epoch 29/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6724 - acc: 0.6056 - val_loss: 0.7277 - val_acc: 0.4750
# Epoch 30/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6587 - acc: 0.6389 - val_loss: 0.7388 - val_acc: 0.4625
# Epoch 31/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6741 - acc: 0.6000 - val_loss: 0.7245 - val_acc: 0.4875
# Epoch 32/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6620 - acc: 0.6222 - val_loss: 0.7272 - val_acc: 0.4875
# Epoch 33/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6684 - acc: 0.6111 - val_loss: 0.7212 - val_acc: 0.5000
# Epoch 34/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6694 - acc: 0.6111 - val_loss: 0.7253 - val_acc: 0.4875
# Epoch 35/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6645 - acc: 0.6222 - val_loss: 0.7208 - val_acc: 0.5000
# Epoch 36/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6714 - acc: 0.6111 - val_loss: 0.7191 - val_acc: 0.5000
# Epoch 37/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6581 - acc: 0.6333 - val_loss: 0.7282 - val_acc: 0.4875
# Epoch 38/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6784 - acc: 0.5944 - val_loss: 0.7234 - val_acc: 0.4875
# Epoch 39/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6670 - acc: 0.6222 - val_loss: 0.7180 - val_acc: 0.5000
# Epoch 40/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6733 - acc: 0.6056 - val_loss: 0.7284 - val_acc: 0.4750
# Epoch 41/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6603 - acc: 0.6278 - val_loss: 0.7326 - val_acc: 0.4750
# Epoch 42/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6695 - acc: 0.6111 - val_loss: 0.7263 - val_acc: 0.4875
# Epoch 43/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6658 - acc: 0.6222 - val_loss: 0.7321 - val_acc: 0.4750
# Epoch 44/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6674 - acc: 0.6111 - val_loss: 0.7392 - val_acc: 0.4625
# Epoch 45/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6706 - acc: 0.6111 - val_loss: 0.7247 - val_acc: 0.4875
# Epoch 46/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6638 - acc: 0.6222 - val_loss: 0.7386 - val_acc: 0.4625
# Epoch 47/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6682 - acc: 0.6111 - val_loss: 0.7260 - val_acc: 0.4875
# Epoch 48/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6606 - acc: 0.6333 - val_loss: 0.7287 - val_acc: 0.4875
# Epoch 49/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6790 - acc: 0.5889 - val_loss: 0.7295 - val_acc: 0.4750
# Epoch 50/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6619 - acc: 0.6278 - val_loss: 0.7377 - val_acc: 0.4625
# Epoch 51/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6719 - acc: 0.6056 - val_loss: 0.7302 - val_acc: 0.4750
# Epoch 52/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6641 - acc: 0.6222 - val_loss: 0.7376 - val_acc: 0.4625
# Epoch 53/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6723 - acc: 0.6056 - val_loss: 0.7240 - val_acc: 0.4875
# Epoch 54/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6631 - acc: 0.6222 - val_loss: 0.7316 - val_acc: 0.4750
# Epoch 55/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6682 - acc: 0.6111 - val_loss: 0.7205 - val_acc: 0.5000
# Epoch 56/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6615 - acc: 0.6278 - val_loss: 0.7332 - val_acc: 0.4750
# Epoch 57/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6680 - acc: 0.6167 - val_loss: 0.7322 - val_acc: 0.4750
# Epoch 58/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6701 - acc: 0.6111 - val_loss: 0.7305 - val_acc: 0.4750
# Epoch 59/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6598 - acc: 0.6278 - val_loss: 0.7347 - val_acc: 0.4750
# Epoch 60/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6775 - acc: 0.5944 - val_loss: 0.7192 - val_acc: 0.5000
# Epoch 61/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6618 - acc: 0.6278 - val_loss: 0.7210 - val_acc: 0.5000
# Epoch 62/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6772 - acc: 0.5944 - val_loss: 0.7236 - val_acc: 0.4875
# Epoch 63/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6616 - acc: 0.6278 - val_loss: 0.7194 - val_acc: 0.5000
# Epoch 64/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6672 - acc: 0.6111 - val_loss: 0.7200 - val_acc: 0.5000
# Epoch 65/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6663 - acc: 0.6167 - val_loss: 0.7259 - val_acc: 0.4875
# Epoch 66/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6662 - acc: 0.6167 - val_loss: 0.7262 - val_acc: 0.4875
# Epoch 67/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6614 - acc: 0.6278 - val_loss: 0.7275 - val_acc: 0.4875
# Epoch 68/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6663 - acc: 0.6167 - val_loss: 0.7339 - val_acc: 0.4750
# Epoch 69/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6769 - acc: 0.5944 - val_loss: 0.7246 - val_acc: 0.4875
# Epoch 70/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6583 - acc: 0.6333 - val_loss: 0.7342 - val_acc: 0.4750
# Epoch 71/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6719 - acc: 0.6056 - val_loss: 0.7316 - val_acc: 0.4750
# Epoch 72/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6642 - acc: 0.6222 - val_loss: 0.7327 - val_acc: 0.4750
# Epoch 73/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6740 - acc: 0.6000 - val_loss: 0.7303 - val_acc: 0.4750
# Epoch 74/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6611 - acc: 0.6278 - val_loss: 0.7326 - val_acc: 0.4750
# Epoch 75/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6719 - acc: 0.6056 - val_loss: 0.7249 - val_acc: 0.4875
# Epoch 76/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6613 - acc: 0.6278 - val_loss: 0.7324 - val_acc: 0.4750
# Epoch 77/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6704 - acc: 0.6056 - val_loss: 0.7320 - val_acc: 0.4750
# Epoch 78/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6590 - acc: 0.6333 - val_loss: 0.7400 - val_acc: 0.4625
# Epoch 79/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6680 - acc: 0.6111 - val_loss: 0.7343 - val_acc: 0.4750
# Epoch 80/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6719 - acc: 0.6056 - val_loss: 0.7321 - val_acc: 0.4750
# Epoch 81/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6617 - acc: 0.6278 - val_loss: 0.7280 - val_acc: 0.4875
# Epoch 82/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6772 - acc: 0.5944 - val_loss: 0.7294 - val_acc: 0.4750
# Epoch 83/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6585 - acc: 0.6333 - val_loss: 0.7211 - val_acc: 0.5000
# Epoch 84/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6759 - acc: 0.5944 - val_loss: 0.7303 - val_acc: 0.4750
# Epoch 85/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6575 - acc: 0.6333 - val_loss: 0.7399 - val_acc: 0.4625
# Epoch 86/100
# 18/18 [==============================] - 32s 2s/step - loss: 0.6732 - acc: 0.6056 - val_loss: 0.7248 - val_acc: 0.4875
# Epoch 87/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6661 - acc: 0.6167 - val_loss: 0.7308 - val_acc: 0.4750
# Epoch 88/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6711 - acc: 0.6056 - val_loss: 0.7185 - val_acc: 0.5000
# Epoch 89/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6515 - acc: 0.6444 - val_loss: 0.7235 - val_acc: 0.5000
# Epoch 90/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6724 - acc: 0.6000 - val_loss: 0.7282 - val_acc: 0.4875
# Epoch 91/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6671 - acc: 0.6167 - val_loss: 0.7214 - val_acc: 0.5000
# Epoch 92/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6687 - acc: 0.6167 - val_loss: 0.7202 - val_acc: 0.5000
# Epoch 93/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6729 - acc: 0.6056 - val_loss: 0.7286 - val_acc: 0.4750
# Epoch 94/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6640 - acc: 0.6222 - val_loss: 0.7192 - val_acc: 0.5000
# Epoch 95/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6695 - acc: 0.6111 - val_loss: 0.7301 - val_acc: 0.4750
# Epoch 96/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6569 - acc: 0.6333 - val_loss: 0.7287 - val_acc: 0.4875
# Epoch 97/100
# 18/18 [==============================] - 31s 2s/step - loss: 0.6733 - acc: 0.6000 - val_loss: 0.7270 - val_acc: 0.4875
# Epoch 98/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6661 - acc: 0.6167 - val_loss: 0.7328 - val_acc: 0.4750
# Epoch 99/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6678 - acc: 0.6111 - val_loss: 0.7385 - val_acc: 0.4625
# Epoch 100/100
# 18/18 [==============================] - 30s 2s/step - loss: 0.6611 - acc: 0.6278 - val_loss: 0.7341 - val_acc: 0.4750

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']


f, (ax1,ax2) = plt.subplots(2,1)

epochs = range(len(acc))

ax1.plot(epochs, acc, 'bo', label='Training acc')
ax1.plot(epochs, val_acc, 'b', label='Validation acc')
ax1.set_title('Training and validation accuracy')
ax1.legend()


ax2.plot(epochs, loss, 'bo', label='Training loss')
ax2.plot(epochs, val_loss, 'b', label='Validation loss')
ax2.set_title('Training and validation loss')
ax2.legend()

plt.show()
